# %%
import pandas as pd

df_ranking_training = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_er_error_analysis_ranking_train.csv')
df_ranking_training['eval_type'] = 'train'
df_ranking_training.head(2)
# Out:
#    id                 name_subjects  \
# 0   0            Dominican Republic
# 1   1  Mighty Morphin Power Rangers
#
#                                        name_relation name_objects  \
# 0               /location/country/form_of_government     Republic
# 1  /tv/tv_program/regular_cast./tv/regular_tv_app...   Wendee Lee
#
#   relation_type                                            triplet  \
# 0           M-N  Dominican Republic | /location/country/form_of...
# 1           1-N  Mighty Morphin Power Rangers | /tv/tv_program/...
#
#    po_to_s_hybrid  po_to_s_standard  \
# 0               0                 0
# 1               0                 0
#
#                              predicted_object_hybrid  \
# 0  ['Republic' 'Democracy' 'Presidential system' ...
# 1  ['Johnny Yong Bosch' 'Wendee Lee' "Liam O'Brie...
#
#                       predicted_object_scores_hybrid  ...  \
# 0  [10.101889610290527, 9.739956855773926, 8.3898...  ...
# 1  [14.309209823608398, 14.113879203796387, 7.993...  ...
#
#                          predicted_relation_standard  \
# 0  ['/location/country/form_of_government'\n '/ed...
# 1  ['/location/hud_county_place/place'\n '/educat...
#
#                             predicted_subject_hybrid  \
# 0  ['Gabon' 'Tanzania' 'Cape Verde' 'Burundi' 'Be...
# 1  ['Mighty Morphin Power Rangers' 'Power Rangers...
#
#                       predicted_subject_score_hybrid  \
# 0  [10.939971923828125, 10.905258178710938, 10.77...
# 1  [14.113032341003418, 8.514370918273926, 7.8727...
#
#                     predicted_subject_score_standard  \
# 0  [12.28516674041748, 12.251543998718262, 12.203...
# 1  [19.89518165588379, 14.366918563842773, 11.103...
#
#                           predicted_subject_standard so_to_p_hybrid  \
# 0        ['Yemen' 'Benin' 'Zambia' 'Somalia' 'Togo']              0
# 1  ['Mighty Morphin Power Rangers' 'Power Rangers...              0
#
#   so_to_p_standard sp_to_o_hybrid  sp_to_o_standard  eval_type
# 0                0              0                 0      train
# 1                1              0                 0      train
#
# [2 rows x 23 columns]

# %%
df_similar_so = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_error_analysis_relations_in_similar_so_all.csv')
df_similar_so['name_relation'] = df_similar_so.name_relation.map(lambda x: ast.literal_eval(x))
df_similar_so.head(2)
# Out:
#                                              so_pair  \
# 0  (500) Days of Summer, _ ,2009 Sundance Film Fe...
# 1            (500) Days of Summer, _ ,United Kingdom
#
#                                        name_relation eval_type  \
# 0  (/film/film/film_festivals, /film/film/release...     train
# 1  (/film/film/distributors./film/film_film_distr...     train
#
#     relation_type        counts  is_similar so_to_p_standard_Hybrid  \
# 0  ('M-1', 'M-1')    (280, 262)        True                  (0, 0)
# 1  ('M-1', 'M-N')  (168, 14121)       False                  (0, 1)
#
#   so_to_p_standard_ER so_to_p_hybrid_Hybrid so_to_p_hybrid_ER  ...  \
# 0              (1, 0)                (0, 0)            (0, 0)  ...
# 1             (6, 13)                (0, 0)            (0, 0)  ...
#
#                     predicted_relation_hybrid_Hybrid  \
# 0                          /film/film/film_festivals
# 1  /film/film/release_date_s./film/film_regional_...
#
#                         predicted_relation_hybrid_ER  \
# 0                          /film/film/film_festivals
# 1  /film/film/release_date_s./film/film_regional_...
#
#   euclidean_dist_standard_Hybrid euclidean_dist_standard_ER  \
# 0                      14.358633                   3.434402
# 1                      13.335735                   4.617963
#
#    euclidean_dist_hybrid_Hybrid  euclidean_dist_hybrid_ER  \
# 0                     12.351998                 12.388579
# 1                     15.251811                 14.911905
#
#    cosine_sim_standard_Hybrid  cosine_sim_standard_ER  \
# 0                    0.668023                0.504762
# 1                    0.589967                0.234951
#
#    cosine_sim_hybrid_Hybrid  cosine_sim_hybrid_ER
# 0                  0.657049              0.674233
# 1                  0.340485              0.283289
#
# [2 rows x 22 columns]
