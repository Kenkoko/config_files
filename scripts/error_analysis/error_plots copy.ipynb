# %%
from collections import Counter

import pandas as pd
import torch
from kge.job.eval import EvaluationJob
from kge.model import KgeModel
from kge.util.io import load_checkpoint
from functools import reduce

PATH = "/work/dhuynh/Workspaces/Thesis/kge/local/experiments/error_analysis"

checkpoint = load_checkpoint(f'{PATH}/best_models/ICLR20/ComplEx/FB237/ER_standard/checkpoint_best.pt')
model = KgeModel.create_from(checkpoint)

# load data
model.dataset.relation_strings(torch.Tensor([1,]).long())
model.dataset.entity_strings(torch.Tensor([1,]).long())

meta_relation = model.dataset._meta['relation_strings']
meta_entity = model.dataset._meta['entity_strings']
# Out:
# Loading configuration of dataset fb15k-237 from /work/dhuynh/Workspaces/Thesis/kge/data/fb15k-237 ...
# Loaded 237 keys from map relation_ids
# Setting reciprocal_relations_model.base_model.entity_embedder.dropout to 0., was set to -0.18433461524546146.
# Loaded 237 keys from map relation_strings
# Loaded 14541 keys from map entity_ids
# Warning: could not find 8 ids in map entity_strings; filling with None.
# Loaded 14541 keys from map entity_strings

# %%
subject_name = 'Stan Lee'
relation_name = '/business/business_operation/operating_income./measurement_unit/dated_money_value/currency'
object_name = 'X-Men (Action/Adventure Film)'

id_subject = meta_entity.index(subject_name)
id_relation = meta_relation.index(relation_name)
id_object = meta_entity.index(object_name)

s = torch.Tensor([id_subject]).long()
p = torch.Tensor([id_relation]).long()
o = torch.Tensor([id_object]).long()

print(model.dataset.entity_strings(s))
print(model.dataset.relation_strings(p))
print(model.dataset.entity_strings(o))
# Out:
# ['Stan Lee']
# ['/business/business_operation/operating_income./measurement_unit/dated_money_value/currency']
# ['X-Men (Action/Adventure Film)']

# %%
true_score = model.score_spo(s, p, o, "o")
true_score
# Out:
# tensor([1.6331], grad_fn=<ViewBackward0>)

# %%
scores = model.score_sp(s, p)                
predicted_o = torch.topk(scores, 15)
predicted_o_indices = predicted_o.indices
predicted_o_score =  predicted_o.values.detach().cpu().numpy().tolist()
list(model.dataset.entity_strings(predicted_o_indices))
# Out:
# [array(['The Lord of the Rings: The Two Towers', 'Austria-Hungary',
#         'France', 'Comedy', 'Scotland', 'United Kingdom',
#         'European Union Member States', 'Ottoman Empire', 'Italy',
#         'Holy Roman Empire', 'Northern Ireland', 'United States Dollar',
#         'The Mummy', 'Video', '38th Daytime Emmy Awards'], dtype='<U37')]

# %%
import copy
eval_type = 'train'
model.config.set("eval.split", eval_type)
valid_data = model.dataset.split(eval_type)
new_dataset = copy.deepcopy(model.dataset)
new_dataset._triples[eval_type] = valid_data[[1, 17, 18, 19, 20, 136, 20451, 12366]]
# new_dataset._triples[eval_type] = valid_data[valid_data[:, 1] == id_relation]
# new_dataset._triples[eval_type] = valid_data[[1]]
# print(model.dataset.entity_strings(new_dataset._triples[eval_type][:, 0]))
# print(model.dataset.relation_strings(new_dataset._triples[eval_type][:, 1]))
# print(model.dataset.entity_strings(new_dataset._triples[eval_type][:, 2]))
# new_dataset._triples[eval_type]

# %%
so_index = model.dataset.index(f"{eval_type}_so_to_p")
so_index.get_all(new_dataset._triples[eval_type][:, [0, 2]])
# Out:
# tensor([[  0,   1],
#         [  1,   6],
#         [  2,  16],
#         [  3,   8],
#         [  4,   7],
#         [  5,  24],
#         [  5,  66],
#         [  6,  24],
#         [  6,  66],
#         [  6, 160],
#         [  7,  45],
#         [  7,  53],
#         [  7,  77]], dtype=torch.int32)

# %%
new_dataset._triples[eval_type]
# Out:
# tensor([[   2,    1,    3],
#         [  34,    6,   35],
#         [  36,   16,   32],
#         [  37,    8,   38],
#         [  39,    7,   40],
#         [ 248,   66,  249],
#         [1798,   66, 1327],
#         [1798,   45, 4657]], dtype=torch.int32)

# %%
score = model.score_so(new_dataset._triples[eval_type][:, 0], new_dataset._triples[eval_type][:, 2])
torch.topk(score, 31).indices
# Out:
# tensor([[293,  81,   1, 105, 318, 183, 339, 456, 146,  80, 201, 184, 376, 210,
#          186, 275,  84, 424,  56,  12, 399, 116, 109, 223, 410, 243, 232, 136,
#          382, 465, 205],
#         [ 91, 120, 293, 225, 373, 390, 166,   6, 392,  34, 108,  38, 318, 460,
#          420, 102, 167, 346, 321,  79, 423, 387, 238, 353, 249, 181, 421, 127,
#          173, 436,  80],
#         [324, 205,  16, 135, 315, 133,  33, 219, 234, 195, 111, 127, 206, 118,
#           62, 143, 427, 139, 252, 146, 150,  91, 398, 120, 199, 291, 182, 185,
#           81, 194,  28],
#         [ 56, 383, 293, 318,  81, 465, 181, 228, 182, 245,   8, 230, 235, 412,
#          210, 467, 290, 425, 196, 418, 188, 429, 175, 146, 240, 471,  53,   3,
#          455, 472, 152],
#         [212,  81, 210, 167, 181,  56,   7, 267, 318, 178, 190, 127, 235, 462,
#          310, 459, 297, 292, 434, 431,  61, 217, 111,  62, 189, 418, 144, 154,
#          389,  69, 218],
#         [ 24, 167,  33,  39, 120, 219, 195, 110, 139, 324, 205, 225, 206, 166,
#          133, 135, 234,  25, 128, 118,  80,  91,  34, 127,  16,  48, 129, 160,
#           62, 331,  66],
#         [167,  24, 182,  39, 108, 225, 160,  33,  91,  34, 232, 120, 209, 110,
#          139, 224,  66, 324, 431, 127, 208, 206, 219, 128, 359, 118, 190, 318,
#          111, 331, 310],
#         [181, 383,  53, 228,  81, 290, 315, 192, 431, 401, 182, 429, 467,  45,
#          412, 293, 282, 164, 318,  77, 314,  62, 196, 433, 175, 418, 119, 356,
#          144, 444,  56]])

# %%
eval.all_ranks
# Out:
# {'sp_to_o': tensor([ 0,  3,  0, 12, 28,  0,  1,  0]),
#  'po_to_s': tensor([ 0,  6, 90,  8,  2, 68, 87,  0]),
#  'so_to_p': tensor([ 2,  7,  2, 10,  6, 30, 16, 13])}

# %%
eval.all_ranks_filt
# Out:
# {'sp_to_o': tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#  'po_to_s': tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#  'so_to_p': tensor([ 2,  7,  2, 10,  6, 29, 14, 12])}

# %%
eval.all_ranks_filt_test
# Out:
# {'sp_to_o': tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#  'po_to_s': tensor([0, 0, 0, 0, 0, 0, 0, 0]),
#  'so_to_p': tensor([ 2,  7,  2, 10,  6, 29, 14, 12])}

# %%
from kge.job.eval import EvaluationJob

eval = EvaluationJob.create(config=model.config, 
                                    dataset=new_dataset, 
                                    model=model)
eval._prepare()
eval._run()
# Out:
# [172246f5]   93372 distinct sp pairs in train
# [172246f5]   56317 distinct po pairs in train
# [172246f5]   12079 distinct sp pairs in valid
# [172246f5]   8033 distinct po pairs in valid
# [172246f5]   13737 distinct sp pairs in test
# [172246f5]   9113 distinct po pairs in test
# [172246f5]   20354 distinct so pairs in test
# [36c46680] Evaluating on train data (epoch -1)...
# [172246f5] Loaded relation index
# [172246f5]   108 relations of type M-N
# [172246f5]   26 relations of type 1-N
# [172246f5]   86 relations of type M-1
# [172246f5]   17 relations of type 1-1
# [36c46680]   batches: 1, mrr (filt.): 0.361 (0.717), hits@1: 0.250 (0.667), hits@1000: 1.000 (1.000)
# [36c46680]   entry_id: 92c67175-affa-48bf-ae62-e25b5d3d7a46
# [36c46680]   epoch: -1
# [36c46680]   epoch_time: 0.06534528732299805
# [36c46680]   event: eval_completed
# [36c46680]   filter_splits:
# [36c46680]   - train
# [36c46680]   - valid
# [36c46680]   hits_at_1: 0.25
# [36c46680]   hits_at_10: 0.625
# [36c46680]   hits_at_100: 1.0
# [36c46680]   hits_at_1000: 1.0
# [36c46680]   hits_at_1000_1-1: 0.0
# [36c46680]   hits_at_1000_1-1_head: 0.0
# [36c46680]   hits_at_1000_1-1_relation: 0.0
# [36c46680]   hits_at_1000_1-1_tail: 0.0
# [36c46680]   hits_at_1000_1-N: 1.0
# [36c46680]   hits_at_1000_1-N_head: 1.0
# [36c46680]   hits_at_1000_1-N_relation: 1.0
# [36c46680]   hits_at_1000_1-N_tail: 1.0
# [36c46680]   hits_at_1000_M-1: 1.0
# [36c46680]   hits_at_1000_M-1_head: 1.0
# [36c46680]   hits_at_1000_M-1_relation: 1.0
# [36c46680]   hits_at_1000_M-1_tail: 1.0
# [36c46680]   hits_at_1000_M-N: 1.0
# [36c46680]   hits_at_1000_M-N_head: 1.0
# [36c46680]   hits_at_1000_M-N_relation: 1.0
# [36c46680]   hits_at_1000_M-N_tail: 1.0
# [36c46680]   hits_at_1000_entity: 1.0
# [36c46680]   hits_at_1000_filtered: 1.0
# [36c46680]   hits_at_1000_filtered_1-1: 0.0
# [36c46680]   hits_at_1000_filtered_1-1_head: 0.0
# [36c46680]   hits_at_1000_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_1000_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_1000_filtered_1-N: 1.0
# [36c46680]   hits_at_1000_filtered_1-N_head: 1.0
# [36c46680]   hits_at_1000_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_1000_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_1000_filtered_M-1: 1.0
# [36c46680]   hits_at_1000_filtered_M-1_head: 1.0
# [36c46680]   hits_at_1000_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_1000_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_1000_filtered_M-N: 1.0
# [36c46680]   hits_at_1000_filtered_M-N_head: 1.0
# [36c46680]   hits_at_1000_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_1000_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_1000_filtered_entity: 1.0
# [36c46680]   hits_at_1000_filtered_head: 1.0
# [36c46680]   hits_at_1000_filtered_relation: 1.0
# [36c46680]   hits_at_1000_filtered_tail: 1.0
# [36c46680]   hits_at_1000_filtered_with_test: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_1000_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_1000_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_1000_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_1000_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_head: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_1000_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_1000_head: 1.0
# [36c46680]   hits_at_1000_relation: 1.0
# [36c46680]   hits_at_1000_tail: 1.0
# [36c46680]   hits_at_100_1-1: 0.0
# [36c46680]   hits_at_100_1-1_head: 0.0
# [36c46680]   hits_at_100_1-1_relation: 0.0
# [36c46680]   hits_at_100_1-1_tail: 0.0
# [36c46680]   hits_at_100_1-N: 1.0
# [36c46680]   hits_at_100_1-N_head: 1.0
# [36c46680]   hits_at_100_1-N_relation: 1.0
# [36c46680]   hits_at_100_1-N_tail: 1.0
# [36c46680]   hits_at_100_M-1: 1.0
# [36c46680]   hits_at_100_M-1_head: 1.0
# [36c46680]   hits_at_100_M-1_relation: 1.0
# [36c46680]   hits_at_100_M-1_tail: 1.0
# [36c46680]   hits_at_100_M-N: 1.0
# [36c46680]   hits_at_100_M-N_head: 1.0
# [36c46680]   hits_at_100_M-N_relation: 1.0
# [36c46680]   hits_at_100_M-N_tail: 1.0
# [36c46680]   hits_at_100_entity: 1.0
# [36c46680]   hits_at_100_filtered: 1.0
# [36c46680]   hits_at_100_filtered_1-1: 0.0
# [36c46680]   hits_at_100_filtered_1-1_head: 0.0
# [36c46680]   hits_at_100_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_100_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_100_filtered_1-N: 1.0
# [36c46680]   hits_at_100_filtered_1-N_head: 1.0
# [36c46680]   hits_at_100_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_100_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_100_filtered_M-1: 1.0
# [36c46680]   hits_at_100_filtered_M-1_head: 1.0
# [36c46680]   hits_at_100_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_100_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_100_filtered_M-N: 1.0
# [36c46680]   hits_at_100_filtered_M-N_head: 1.0
# [36c46680]   hits_at_100_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_100_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_100_filtered_entity: 1.0
# [36c46680]   hits_at_100_filtered_head: 1.0
# [36c46680]   hits_at_100_filtered_relation: 1.0
# [36c46680]   hits_at_100_filtered_tail: 1.0
# [36c46680]   hits_at_100_filtered_with_test: 1.0
# [36c46680]   hits_at_100_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_100_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_100_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_100_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_100_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_100_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_100_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_100_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_100_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_100_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_100_filtered_with_test_head: 1.0
# [36c46680]   hits_at_100_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_100_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_100_head: 1.0
# [36c46680]   hits_at_100_relation: 1.0
# [36c46680]   hits_at_100_tail: 1.0
# [36c46680]   hits_at_10_1-1: 0.0
# [36c46680]   hits_at_10_1-1_head: 0.0
# [36c46680]   hits_at_10_1-1_relation: 0.0
# [36c46680]   hits_at_10_1-1_tail: 0.0
# [36c46680]   hits_at_10_1-N: 1.0
# [36c46680]   hits_at_10_1-N_head: 1.0
# [36c46680]   hits_at_10_1-N_relation: 1.0
# [36c46680]   hits_at_10_1-N_tail: 1.0
# [36c46680]   hits_at_10_M-1: 0.6666666666666666
# [36c46680]   hits_at_10_M-1_head: 0.0
# [36c46680]   hits_at_10_M-1_relation: 1.0
# [36c46680]   hits_at_10_M-1_tail: 1.0
# [36c46680]   hits_at_10_M-N: 0.5555555555555556
# [36c46680]   hits_at_10_M-N_head: 0.6666666666666666
# [36c46680]   hits_at_10_M-N_relation: 0.3333333333333333
# [36c46680]   hits_at_10_M-N_tail: 0.6666666666666666
# [36c46680]   hits_at_10_entity: 0.6875
# [36c46680]   hits_at_10_filtered: 0.8333333333333334
# [36c46680]   hits_at_10_filtered_1-1: 0.0
# [36c46680]   hits_at_10_filtered_1-1_head: 0.0
# [36c46680]   hits_at_10_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_10_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_10_filtered_1-N: 1.0
# [36c46680]   hits_at_10_filtered_1-N_head: 1.0
# [36c46680]   hits_at_10_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_10_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_10_filtered_M-1: 1.0
# [36c46680]   hits_at_10_filtered_M-1_head: 1.0
# [36c46680]   hits_at_10_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_10_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_10_filtered_M-N: 0.7777777777777778
# [36c46680]   hits_at_10_filtered_M-N_head: 1.0
# [36c46680]   hits_at_10_filtered_M-N_relation: 0.3333333333333333
# [36c46680]   hits_at_10_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_10_filtered_entity: 1.0
# [36c46680]   hits_at_10_filtered_head: 1.0
# [36c46680]   hits_at_10_filtered_relation: 0.5
# [36c46680]   hits_at_10_filtered_tail: 1.0
# [36c46680]   hits_at_10_filtered_with_test: 0.8333333333333334
# [36c46680]   hits_at_10_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_10_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_10_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_10_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_10_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_10_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_10_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_10_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_10_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_10_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_10_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_10_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_10_filtered_with_test_M-N: 0.7777777777777778
# [36c46680]   hits_at_10_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_10_filtered_with_test_M-N_relation: 0.3333333333333333
# [36c46680]   hits_at_10_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_10_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_10_filtered_with_test_head: 1.0
# [36c46680]   hits_at_10_filtered_with_test_relation: 0.5
# [36c46680]   hits_at_10_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_10_head: 0.625
# [36c46680]   hits_at_10_relation: 0.5
# [36c46680]   hits_at_10_tail: 0.75
# [36c46680]   hits_at_1_1-1: 0.0
# [36c46680]   hits_at_1_1-1_head: 0.0
# [36c46680]   hits_at_1_1-1_relation: 0.0
# [36c46680]   hits_at_1_1-1_tail: 0.0
# [36c46680]   hits_at_1_1-N: 0.6666666666666666
# [36c46680]   hits_at_1_1-N_head: 1.0
# [36c46680]   hits_at_1_1-N_relation: 0.0
# [36c46680]   hits_at_1_1-N_tail: 1.0
# [36c46680]   hits_at_1_M-1: 0.3333333333333333
# [36c46680]   hits_at_1_M-1_head: 0.0
# [36c46680]   hits_at_1_M-1_relation: 0.0
# [36c46680]   hits_at_1_M-1_tail: 1.0
# [36c46680]   hits_at_1_M-N: 0.16666666666666666
# [36c46680]   hits_at_1_M-N_head: 0.16666666666666666
# [36c46680]   hits_at_1_M-N_relation: 0.0
# [36c46680]   hits_at_1_M-N_tail: 0.3333333333333333
# [36c46680]   hits_at_1_entity: 0.375
# [36c46680]   hits_at_1_filtered: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_1-1: 0.0
# [36c46680]   hits_at_1_filtered_1-1_head: 0.0
# [36c46680]   hits_at_1_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_1_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_1_filtered_1-N: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_1-N_head: 1.0
# [36c46680]   hits_at_1_filtered_1-N_relation: 0.0
# [36c46680]   hits_at_1_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_1_filtered_M-1: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_M-1_head: 1.0
# [36c46680]   hits_at_1_filtered_M-1_relation: 0.0
# [36c46680]   hits_at_1_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_1_filtered_M-N: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_M-N_head: 1.0
# [36c46680]   hits_at_1_filtered_M-N_relation: 0.0
# [36c46680]   hits_at_1_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_1_filtered_entity: 1.0
# [36c46680]   hits_at_1_filtered_head: 1.0
# [36c46680]   hits_at_1_filtered_relation: 0.0
# [36c46680]   hits_at_1_filtered_tail: 1.0
# [36c46680]   hits_at_1_filtered_with_test: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_1_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_1_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_1_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_1_filtered_with_test_1-N: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_1_filtered_with_test_1-N_relation: 0.0
# [36c46680]   hits_at_1_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_1_filtered_with_test_M-1: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_1_filtered_with_test_M-1_relation: 0.0
# [36c46680]   hits_at_1_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_1_filtered_with_test_M-N: 0.6666666666666666
# [36c46680]   hits_at_1_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_1_filtered_with_test_M-N_relation: 0.0
# [36c46680]   hits_at_1_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_1_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_1_filtered_with_test_head: 1.0
# [36c46680]   hits_at_1_filtered_with_test_relation: 0.0
# [36c46680]   hits_at_1_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_1_head: 0.25
# [36c46680]   hits_at_1_relation: 0.0
# [36c46680]   hits_at_1_tail: 0.5
# [36c46680]   hits_at_200: 1.0
# [36c46680]   hits_at_200_1-1: 0.0
# [36c46680]   hits_at_200_1-1_head: 0.0
# [36c46680]   hits_at_200_1-1_relation: 0.0
# [36c46680]   hits_at_200_1-1_tail: 0.0
# [36c46680]   hits_at_200_1-N: 1.0
# [36c46680]   hits_at_200_1-N_head: 1.0
# [36c46680]   hits_at_200_1-N_relation: 1.0
# [36c46680]   hits_at_200_1-N_tail: 1.0
# [36c46680]   hits_at_200_M-1: 1.0
# [36c46680]   hits_at_200_M-1_head: 1.0
# [36c46680]   hits_at_200_M-1_relation: 1.0
# [36c46680]   hits_at_200_M-1_tail: 1.0
# [36c46680]   hits_at_200_M-N: 1.0
# [36c46680]   hits_at_200_M-N_head: 1.0
# [36c46680]   hits_at_200_M-N_relation: 1.0
# [36c46680]   hits_at_200_M-N_tail: 1.0
# [36c46680]   hits_at_200_entity: 1.0
# [36c46680]   hits_at_200_filtered: 1.0
# [36c46680]   hits_at_200_filtered_1-1: 0.0
# [36c46680]   hits_at_200_filtered_1-1_head: 0.0
# [36c46680]   hits_at_200_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_200_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_200_filtered_1-N: 1.0
# [36c46680]   hits_at_200_filtered_1-N_head: 1.0
# [36c46680]   hits_at_200_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_200_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_200_filtered_M-1: 1.0
# [36c46680]   hits_at_200_filtered_M-1_head: 1.0
# [36c46680]   hits_at_200_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_200_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_200_filtered_M-N: 1.0
# [36c46680]   hits_at_200_filtered_M-N_head: 1.0
# [36c46680]   hits_at_200_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_200_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_200_filtered_entity: 1.0
# [36c46680]   hits_at_200_filtered_head: 1.0
# [36c46680]   hits_at_200_filtered_relation: 1.0
# [36c46680]   hits_at_200_filtered_tail: 1.0
# [36c46680]   hits_at_200_filtered_with_test: 1.0
# [36c46680]   hits_at_200_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_200_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_200_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_200_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_200_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_200_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_200_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_200_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_200_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_200_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_200_filtered_with_test_head: 1.0
# [36c46680]   hits_at_200_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_200_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_200_head: 1.0
# [36c46680]   hits_at_200_relation: 1.0
# [36c46680]   hits_at_200_tail: 1.0
# [36c46680]   hits_at_3: 0.4166666666666667
# [36c46680]   hits_at_300: 1.0
# [36c46680]   hits_at_300_1-1: 0.0
# [36c46680]   hits_at_300_1-1_head: 0.0
# [36c46680]   hits_at_300_1-1_relation: 0.0
# [36c46680]   hits_at_300_1-1_tail: 0.0
# [36c46680]   hits_at_300_1-N: 1.0
# [36c46680]   hits_at_300_1-N_head: 1.0
# [36c46680]   hits_at_300_1-N_relation: 1.0
# [36c46680]   hits_at_300_1-N_tail: 1.0
# [36c46680]   hits_at_300_M-1: 1.0
# [36c46680]   hits_at_300_M-1_head: 1.0
# [36c46680]   hits_at_300_M-1_relation: 1.0
# [36c46680]   hits_at_300_M-1_tail: 1.0
# [36c46680]   hits_at_300_M-N: 1.0
# [36c46680]   hits_at_300_M-N_head: 1.0
# [36c46680]   hits_at_300_M-N_relation: 1.0
# [36c46680]   hits_at_300_M-N_tail: 1.0
# [36c46680]   hits_at_300_entity: 1.0
# [36c46680]   hits_at_300_filtered: 1.0
# [36c46680]   hits_at_300_filtered_1-1: 0.0
# [36c46680]   hits_at_300_filtered_1-1_head: 0.0
# [36c46680]   hits_at_300_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_300_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_300_filtered_1-N: 1.0
# [36c46680]   hits_at_300_filtered_1-N_head: 1.0
# [36c46680]   hits_at_300_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_300_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_300_filtered_M-1: 1.0
# [36c46680]   hits_at_300_filtered_M-1_head: 1.0
# [36c46680]   hits_at_300_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_300_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_300_filtered_M-N: 1.0
# [36c46680]   hits_at_300_filtered_M-N_head: 1.0
# [36c46680]   hits_at_300_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_300_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_300_filtered_entity: 1.0
# [36c46680]   hits_at_300_filtered_head: 1.0
# [36c46680]   hits_at_300_filtered_relation: 1.0
# [36c46680]   hits_at_300_filtered_tail: 1.0
# [36c46680]   hits_at_300_filtered_with_test: 1.0
# [36c46680]   hits_at_300_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_300_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_300_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_300_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_300_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_300_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_300_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_300_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_300_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_300_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_300_filtered_with_test_head: 1.0
# [36c46680]   hits_at_300_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_300_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_300_head: 1.0
# [36c46680]   hits_at_300_relation: 1.0
# [36c46680]   hits_at_300_tail: 1.0
# [36c46680]   hits_at_3_1-1: 0.0
# [36c46680]   hits_at_3_1-1_head: 0.0
# [36c46680]   hits_at_3_1-1_relation: 0.0
# [36c46680]   hits_at_3_1-1_tail: 0.0
# [36c46680]   hits_at_3_1-N: 1.0
# [36c46680]   hits_at_3_1-N_head: 1.0
# [36c46680]   hits_at_3_1-N_relation: 1.0
# [36c46680]   hits_at_3_1-N_tail: 1.0
# [36c46680]   hits_at_3_M-1: 0.6666666666666666
# [36c46680]   hits_at_3_M-1_head: 0.0
# [36c46680]   hits_at_3_M-1_relation: 1.0
# [36c46680]   hits_at_3_M-1_tail: 1.0
# [36c46680]   hits_at_3_M-N: 0.2777777777777778
# [36c46680]   hits_at_3_M-N_head: 0.3333333333333333
# [36c46680]   hits_at_3_M-N_relation: 0.0
# [36c46680]   hits_at_3_M-N_tail: 0.5
# [36c46680]   hits_at_3_entity: 0.5
# [36c46680]   hits_at_3_filtered: 0.75
# [36c46680]   hits_at_3_filtered_1-1: 0.0
# [36c46680]   hits_at_3_filtered_1-1_head: 0.0
# [36c46680]   hits_at_3_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_3_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_3_filtered_1-N: 1.0
# [36c46680]   hits_at_3_filtered_1-N_head: 1.0
# [36c46680]   hits_at_3_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_3_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_3_filtered_M-1: 1.0
# [36c46680]   hits_at_3_filtered_M-1_head: 1.0
# [36c46680]   hits_at_3_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_3_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_3_filtered_M-N: 0.6666666666666666
# [36c46680]   hits_at_3_filtered_M-N_head: 1.0
# [36c46680]   hits_at_3_filtered_M-N_relation: 0.0
# [36c46680]   hits_at_3_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_3_filtered_entity: 1.0
# [36c46680]   hits_at_3_filtered_head: 1.0
# [36c46680]   hits_at_3_filtered_relation: 0.25
# [36c46680]   hits_at_3_filtered_tail: 1.0
# [36c46680]   hits_at_3_filtered_with_test: 0.75
# [36c46680]   hits_at_3_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_3_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_3_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_3_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_3_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_3_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_3_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_3_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_3_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_3_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_3_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_3_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_3_filtered_with_test_M-N: 0.6666666666666666
# [36c46680]   hits_at_3_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_3_filtered_with_test_M-N_relation: 0.0
# [36c46680]   hits_at_3_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_3_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_3_filtered_with_test_head: 1.0
# [36c46680]   hits_at_3_filtered_with_test_relation: 0.25
# [36c46680]   hits_at_3_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_3_head: 0.375
# [36c46680]   hits_at_3_relation: 0.25
# [36c46680]   hits_at_3_tail: 0.625
# [36c46680]   hits_at_400: 1.0
# [36c46680]   hits_at_400_1-1: 0.0
# [36c46680]   hits_at_400_1-1_head: 0.0
# [36c46680]   hits_at_400_1-1_relation: 0.0
# [36c46680]   hits_at_400_1-1_tail: 0.0
# [36c46680]   hits_at_400_1-N: 1.0
# [36c46680]   hits_at_400_1-N_head: 1.0
# [36c46680]   hits_at_400_1-N_relation: 1.0
# [36c46680]   hits_at_400_1-N_tail: 1.0
# [36c46680]   hits_at_400_M-1: 1.0
# [36c46680]   hits_at_400_M-1_head: 1.0
# [36c46680]   hits_at_400_M-1_relation: 1.0
# [36c46680]   hits_at_400_M-1_tail: 1.0
# [36c46680]   hits_at_400_M-N: 1.0
# [36c46680]   hits_at_400_M-N_head: 1.0
# [36c46680]   hits_at_400_M-N_relation: 1.0
# [36c46680]   hits_at_400_M-N_tail: 1.0
# [36c46680]   hits_at_400_entity: 1.0
# [36c46680]   hits_at_400_filtered: 1.0
# [36c46680]   hits_at_400_filtered_1-1: 0.0
# [36c46680]   hits_at_400_filtered_1-1_head: 0.0
# [36c46680]   hits_at_400_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_400_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_400_filtered_1-N: 1.0
# [36c46680]   hits_at_400_filtered_1-N_head: 1.0
# [36c46680]   hits_at_400_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_400_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_400_filtered_M-1: 1.0
# [36c46680]   hits_at_400_filtered_M-1_head: 1.0
# [36c46680]   hits_at_400_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_400_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_400_filtered_M-N: 1.0
# [36c46680]   hits_at_400_filtered_M-N_head: 1.0
# [36c46680]   hits_at_400_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_400_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_400_filtered_entity: 1.0
# [36c46680]   hits_at_400_filtered_head: 1.0
# [36c46680]   hits_at_400_filtered_relation: 1.0
# [36c46680]   hits_at_400_filtered_tail: 1.0
# [36c46680]   hits_at_400_filtered_with_test: 1.0
# [36c46680]   hits_at_400_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_400_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_400_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_400_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_400_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_400_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_400_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_400_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_400_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_400_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_400_filtered_with_test_head: 1.0
# [36c46680]   hits_at_400_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_400_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_400_head: 1.0
# [36c46680]   hits_at_400_relation: 1.0
# [36c46680]   hits_at_400_tail: 1.0
# [36c46680]   hits_at_50: 0.875
# [36c46680]   hits_at_500: 1.0
# [36c46680]   hits_at_500_1-1: 0.0
# [36c46680]   hits_at_500_1-1_head: 0.0
# [36c46680]   hits_at_500_1-1_relation: 0.0
# [36c46680]   hits_at_500_1-1_tail: 0.0
# [36c46680]   hits_at_500_1-N: 1.0
# [36c46680]   hits_at_500_1-N_head: 1.0
# [36c46680]   hits_at_500_1-N_relation: 1.0
# [36c46680]   hits_at_500_1-N_tail: 1.0
# [36c46680]   hits_at_500_M-1: 1.0
# [36c46680]   hits_at_500_M-1_head: 1.0
# [36c46680]   hits_at_500_M-1_relation: 1.0
# [36c46680]   hits_at_500_M-1_tail: 1.0
# [36c46680]   hits_at_500_M-N: 1.0
# [36c46680]   hits_at_500_M-N_head: 1.0
# [36c46680]   hits_at_500_M-N_relation: 1.0
# [36c46680]   hits_at_500_M-N_tail: 1.0
# [36c46680]   hits_at_500_entity: 1.0
# [36c46680]   hits_at_500_filtered: 1.0
# [36c46680]   hits_at_500_filtered_1-1: 0.0
# [36c46680]   hits_at_500_filtered_1-1_head: 0.0
# [36c46680]   hits_at_500_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_500_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_500_filtered_1-N: 1.0
# [36c46680]   hits_at_500_filtered_1-N_head: 1.0
# [36c46680]   hits_at_500_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_500_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_500_filtered_M-1: 1.0
# [36c46680]   hits_at_500_filtered_M-1_head: 1.0
# [36c46680]   hits_at_500_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_500_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_500_filtered_M-N: 1.0
# [36c46680]   hits_at_500_filtered_M-N_head: 1.0
# [36c46680]   hits_at_500_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_500_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_500_filtered_entity: 1.0
# [36c46680]   hits_at_500_filtered_head: 1.0
# [36c46680]   hits_at_500_filtered_relation: 1.0
# [36c46680]   hits_at_500_filtered_tail: 1.0
# [36c46680]   hits_at_500_filtered_with_test: 1.0
# [36c46680]   hits_at_500_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_500_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_500_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_500_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_500_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_500_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_500_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_500_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_500_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_500_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_500_filtered_with_test_head: 1.0
# [36c46680]   hits_at_500_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_500_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_500_head: 1.0
# [36c46680]   hits_at_500_relation: 1.0
# [36c46680]   hits_at_500_tail: 1.0
# [36c46680]   hits_at_50_1-1: 0.0
# [36c46680]   hits_at_50_1-1_head: 0.0
# [36c46680]   hits_at_50_1-1_relation: 0.0
# [36c46680]   hits_at_50_1-1_tail: 0.0
# [36c46680]   hits_at_50_1-N: 1.0
# [36c46680]   hits_at_50_1-N_head: 1.0
# [36c46680]   hits_at_50_1-N_relation: 1.0
# [36c46680]   hits_at_50_1-N_tail: 1.0
# [36c46680]   hits_at_50_M-1: 0.6666666666666666
# [36c46680]   hits_at_50_M-1_head: 0.0
# [36c46680]   hits_at_50_M-1_relation: 1.0
# [36c46680]   hits_at_50_M-1_tail: 1.0
# [36c46680]   hits_at_50_M-N: 0.8888888888888888
# [36c46680]   hits_at_50_M-N_head: 0.6666666666666666
# [36c46680]   hits_at_50_M-N_relation: 1.0
# [36c46680]   hits_at_50_M-N_tail: 1.0
# [36c46680]   hits_at_50_entity: 0.8125
# [36c46680]   hits_at_50_filtered: 1.0
# [36c46680]   hits_at_50_filtered_1-1: 0.0
# [36c46680]   hits_at_50_filtered_1-1_head: 0.0
# [36c46680]   hits_at_50_filtered_1-1_relation: 0.0
# [36c46680]   hits_at_50_filtered_1-1_tail: 0.0
# [36c46680]   hits_at_50_filtered_1-N: 1.0
# [36c46680]   hits_at_50_filtered_1-N_head: 1.0
# [36c46680]   hits_at_50_filtered_1-N_relation: 1.0
# [36c46680]   hits_at_50_filtered_1-N_tail: 1.0
# [36c46680]   hits_at_50_filtered_M-1: 1.0
# [36c46680]   hits_at_50_filtered_M-1_head: 1.0
# [36c46680]   hits_at_50_filtered_M-1_relation: 1.0
# [36c46680]   hits_at_50_filtered_M-1_tail: 1.0
# [36c46680]   hits_at_50_filtered_M-N: 1.0
# [36c46680]   hits_at_50_filtered_M-N_head: 1.0
# [36c46680]   hits_at_50_filtered_M-N_relation: 1.0
# [36c46680]   hits_at_50_filtered_M-N_tail: 1.0
# [36c46680]   hits_at_50_filtered_entity: 1.0
# [36c46680]   hits_at_50_filtered_head: 1.0
# [36c46680]   hits_at_50_filtered_relation: 1.0
# [36c46680]   hits_at_50_filtered_tail: 1.0
# [36c46680]   hits_at_50_filtered_with_test: 1.0
# [36c46680]   hits_at_50_filtered_with_test_1-1: 0.0
# [36c46680]   hits_at_50_filtered_with_test_1-1_head: 0.0
# [36c46680]   hits_at_50_filtered_with_test_1-1_relation: 0.0
# [36c46680]   hits_at_50_filtered_with_test_1-1_tail: 0.0
# [36c46680]   hits_at_50_filtered_with_test_1-N: 1.0
# [36c46680]   hits_at_50_filtered_with_test_1-N_head: 1.0
# [36c46680]   hits_at_50_filtered_with_test_1-N_relation: 1.0
# [36c46680]   hits_at_50_filtered_with_test_1-N_tail: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-1: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-1_head: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-1_relation: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-1_tail: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-N: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-N_head: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-N_relation: 1.0
# [36c46680]   hits_at_50_filtered_with_test_M-N_tail: 1.0
# [36c46680]   hits_at_50_filtered_with_test_entity: 1.0
# [36c46680]   hits_at_50_filtered_with_test_head: 1.0
# [36c46680]   hits_at_50_filtered_with_test_relation: 1.0
# [36c46680]   hits_at_50_filtered_with_test_tail: 1.0
# [36c46680]   hits_at_50_head: 0.625
# [36c46680]   hits_at_50_relation: 1.0
# [36c46680]   hits_at_50_tail: 1.0
# [36c46680]   job: train
# [36c46680]   job_id: 36c46680-fb22-4a0f-af06-55d872254afd
# [36c46680]   mean_rank: 17.291666666666668
# [36c46680]   mean_rank_1-1: 0.0
# [36c46680]   mean_rank_1-1_head: 0.0
# [36c46680]   mean_rank_1-1_relation: 0.0
# [36c46680]   mean_rank_1-1_tail: 0.0
# [36c46680]   mean_rank_1-N: 1.6666666666666667
# [36c46680]   mean_rank_1-N_head: 1.0
# [36c46680]   mean_rank_1-N_relation: 3.0
# [36c46680]   mean_rank_1-N_tail: 1.0
# [36c46680]   mean_rank_M-1: 31.666666666666668
# [36c46680]   mean_rank_M-1_head: 91.0
# [36c46680]   mean_rank_M-1_relation: 3.0
# [36c46680]   mean_rank_M-1_tail: 1.0
# [36c46680]   mean_rank_M-N: 17.5
# [36c46680]   mean_rank_M-N_head: 29.5
# [36c46680]   mean_rank_M-N_relation: 14.666666666666666
# [36c46680]   mean_rank_M-N_tail: 8.333333333333334
# [36c46680]   mean_rank_entity: 20.0625
# [36c46680]   mean_rank_filtered: 4.416666666666667
# [36c46680]   mean_rank_filtered_1-1: 0.0
# [36c46680]   mean_rank_filtered_1-1_head: 0.0
# [36c46680]   mean_rank_filtered_1-1_relation: 0.0
# [36c46680]   mean_rank_filtered_1-1_tail: 0.0
# [36c46680]   mean_rank_filtered_1-N: 1.6666666666666667
# [36c46680]   mean_rank_filtered_1-N_head: 1.0
# [36c46680]   mean_rank_filtered_1-N_relation: 3.0
# [36c46680]   mean_rank_filtered_1-N_tail: 1.0
# [36c46680]   mean_rank_filtered_M-1: 1.6666666666666667
# [36c46680]   mean_rank_filtered_M-1_head: 1.0
# [36c46680]   mean_rank_filtered_M-1_relation: 3.0
# [36c46680]   mean_rank_filtered_M-1_tail: 1.0
# [36c46680]   mean_rank_filtered_M-N: 5.333333333333333
# [36c46680]   mean_rank_filtered_M-N_head: 1.0
# [36c46680]   mean_rank_filtered_M-N_relation: 14.0
# [36c46680]   mean_rank_filtered_M-N_tail: 1.0
# [36c46680]   mean_rank_filtered_entity: 1.0
# [36c46680]   mean_rank_filtered_head: 1.0
# [36c46680]   mean_rank_filtered_relation: 11.25
# [36c46680]   mean_rank_filtered_tail: 1.0
# [36c46680]   mean_rank_filtered_with_test: 4.416666666666667
# [36c46680]   mean_rank_filtered_with_test_1-1: 0.0
# [36c46680]   mean_rank_filtered_with_test_1-1_head: 0.0
# [36c46680]   mean_rank_filtered_with_test_1-1_relation: 0.0
# [36c46680]   mean_rank_filtered_with_test_1-1_tail: 0.0
# [36c46680]   mean_rank_filtered_with_test_1-N: 1.6666666666666667
# [36c46680]   mean_rank_filtered_with_test_1-N_head: 1.0
# [36c46680]   mean_rank_filtered_with_test_1-N_relation: 3.0
# [36c46680]   mean_rank_filtered_with_test_1-N_tail: 1.0
# [36c46680]   mean_rank_filtered_with_test_M-1: 1.6666666666666667
# [36c46680]   mean_rank_filtered_with_test_M-1_head: 1.0
# [36c46680]   mean_rank_filtered_with_test_M-1_relation: 3.0
# [36c46680]   mean_rank_filtered_with_test_M-1_tail: 1.0
# [36c46680]   mean_rank_filtered_with_test_M-N: 5.333333333333333
# [36c46680]   mean_rank_filtered_with_test_M-N_head: 1.0
# [36c46680]   mean_rank_filtered_with_test_M-N_relation: 14.0
# [36c46680]   mean_rank_filtered_with_test_M-N_tail: 1.0
# [36c46680]   mean_rank_filtered_with_test_entity: 1.0
# [36c46680]   mean_rank_filtered_with_test_head: 1.0
# [36c46680]   mean_rank_filtered_with_test_relation: 11.25
# [36c46680]   mean_rank_filtered_with_test_tail: 1.0
# [36c46680]   mean_rank_head: 33.625
# [36c46680]   mean_rank_relation: 11.75
# [36c46680]   mean_rank_tail: 6.5
# [36c46680]   mean_reciprocal_rank: 0.3613956769307454
# [36c46680]   mean_reciprocal_rank_1-1: 0.0
# [36c46680]   mean_reciprocal_rank_1-1_head: 0.0
# [36c46680]   mean_reciprocal_rank_1-1_relation: 0.0
# [36c46680]   mean_reciprocal_rank_1-1_tail: 0.0
# [36c46680]   mean_reciprocal_rank_1-N: 0.7777777512868246
# [36c46680]   mean_reciprocal_rank_1-N_head: 1.0
# [36c46680]   mean_reciprocal_rank_1-N_relation: 0.3333333432674408
# [36c46680]   mean_reciprocal_rank_1-N_tail: 1.0
# [36c46680]   mean_reciprocal_rank_M-1: 0.44810744126637775
# [36c46680]   mean_reciprocal_rank_M-1_head: 0.010989011265337467
# [36c46680]   mean_reciprocal_rank_M-1_relation: 0.3333333432674408
# [36c46680]   mean_reciprocal_rank_M-1_tail: 1.0
# [36c46680]   mean_reciprocal_rank_M-N: 0.27754667070176864
# [36c46680]   mean_reciprocal_rank_M-N_head: 0.2688596844673157
# [36c46680]   mean_reciprocal_rank_M-N_relation: 0.08687940239906311
# [36c46680]   mean_reciprocal_rank_M-N_tail: 0.47690097490946454
# [36c46680]   mean_reciprocal_rank_entity: 0.4678470492362976
# [36c46680]   mean_reciprocal_rank_filtered: 0.7167648474375407
# [36c46680]   mean_reciprocal_rank_filtered_1-1: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_1-1_head: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_1-1_relation: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_1-1_tail: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_1-N: 0.7777777512868246
# [36c46680]   mean_reciprocal_rank_filtered_1-N_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_1-N_relation: 0.3333333432674408
# [36c46680]   mean_reciprocal_rank_filtered_1-N_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_M-1: 0.7777777512868246
# [36c46680]   mean_reciprocal_rank_filtered_M-1_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_M-1_relation: 0.3333333432674408
# [36c46680]   mean_reciprocal_rank_filtered_M-1_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_M-N: 0.696427239312066
# [36c46680]   mean_reciprocal_rank_filtered_M-N_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_M-N_relation: 0.08928155899047852
# [36c46680]   mean_reciprocal_rank_filtered_M-N_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_entity: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_relation: 0.1502944976091385
# [36c46680]   mean_reciprocal_rank_filtered_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test: 0.7167648474375407
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-1: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-1_head: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-1_relation: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-1_tail: 0.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-N: 0.7777777512868246
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-N_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-N_relation: 0.3333333432674408
# [36c46680]   mean_reciprocal_rank_filtered_with_test_1-N_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-1: 0.7777777512868246
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-1_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-1_relation: 0.3333333432674408
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-1_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-N: 0.696427239312066
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-N_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-N_relation: 0.08928155899047852
# [36c46680]   mean_reciprocal_rank_filtered_with_test_M-N_tail: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_entity: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_head: 1.0
# [36c46680]   mean_reciprocal_rank_filtered_with_test_relation: 0.1502944976091385
# [36c46680]   mean_reciprocal_rank_filtered_with_test_tail: 1.0
# [36c46680]   mean_reciprocal_rank_head: 0.3280183970928192
# [36c46680]   mean_reciprocal_rank_relation: 0.14849288761615753
# [36c46680]   mean_reciprocal_rank_tail: 0.6076757311820984
# [36c46680]   num_parameters: 7687680
# [36c46680]   scope: epoch
# [36c46680]   size: 8
# [36c46680]   split: train
# [36c46680]   timestamp: 1655895991.7743285
# [36c46680]   type: entity_ranking
# [36c46680] Finished evaluating on train split.
# /work/dhuynh/Workspaces/Thesis/kge/kge/job/eval_entity_ranking.py:743: UserWarning:
#
# __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
# {'job_id': '36c46680-fb22-4a0f-af06-55d872254afd',
#  'job': 'train',
#  'type': 'entity_ranking',
#  'scope': 'epoch',
#  'split': 'train',
#  'filter_splits': ['train', 'valid'],
#  'epoch': -1,
#  'batches': 1,
#  'size': 8,
#  'epoch_time': 0.06534528732299805,
#  'event': 'eval_completed',
#  'mean_rank': 17.291666666666668,
#  'mean_reciprocal_rank': 0.3613956769307454,
#  'hits_at_1': 0.25,
#  'hits_at_3': 0.4166666666666667,
#  'hits_at_10': 0.625,
#  'hits_at_50': 0.875,
#  'hits_at_100': 1.0,
#  'hits_at_200': 1.0,
#  'hits_at_300': 1.0,
#  'hits_at_400': 1.0,
#  'hits_at_500': 1.0,
#  'hits_at_1000': 1.0,
#  'mean_rank_filtered': 4.416666666666667,
#  'mean_reciprocal_rank_filtered': 0.7167648474375407,
#  'hits_at_1_filtered': 0.6666666666666666,
#  'hits_at_3_filtered': 0.75,
#  'hits_at_10_filtered': 0.8333333333333334,
#  'hits_at_50_filtered': 1.0,
#  'hits_at_100_filtered': 1.0,
#  'hits_at_200_filtered': 1.0,
#  'hits_at_300_filtered': 1.0,
#  'hits_at_400_filtered': 1.0,
#  'hits_at_500_filtered': 1.0,
#  'hits_at_1000_filtered': 1.0,
#  'mean_rank_filtered_with_test': 4.416666666666667,
#  'mean_reciprocal_rank_filtered_with_test': 0.7167648474375407,
#  'hits_at_1_filtered_with_test': 0.6666666666666666,
#  'hits_at_3_filtered_with_test': 0.75,
#  'hits_at_10_filtered_with_test': 0.8333333333333334,
#  'hits_at_50_filtered_with_test': 1.0,
#  'hits_at_100_filtered_with_test': 1.0,
#  'hits_at_200_filtered_with_test': 1.0,
#  'hits_at_300_filtered_with_test': 1.0,
#  'hits_at_400_filtered_with_test': 1.0,
#  'hits_at_500_filtered_with_test': 1.0,
#  'hits_at_1000_filtered_with_test': 1.0,
#  'mean_rank_head': 33.625,
#  'mean_reciprocal_rank_head': 0.3280183970928192,
#  'hits_at_1_head': 0.25,
#  'hits_at_3_head': 0.375,
#  'hits_at_10_head': 0.625,
#  'hits_at_50_head': 0.625,
#  'hits_at_100_head': 1.0,
#  'hits_at_200_head': 1.0,
#  'hits_at_300_head': 1.0,
#  'hits_at_400_head': 1.0,
#  'hits_at_500_head': 1.0,
#  'hits_at_1000_head': 1.0,
#  'mean_rank_filtered_head': 1.0,
#  'mean_reciprocal_rank_filtered_head': 1.0,
#  'hits_at_1_filtered_head': 1.0,
#  'hits_at_3_filtered_head': 1.0,
#  'hits_at_10_filtered_head': 1.0,
#  'hits_at_50_filtered_head': 1.0,
#  'hits_at_100_filtered_head': 1.0,
#  'hits_at_200_filtered_head': 1.0,
#  'hits_at_300_filtered_head': 1.0,
#  'hits_at_400_filtered_head': 1.0,
#  'hits_at_500_filtered_head': 1.0,
#  'hits_at_1000_filtered_head': 1.0,
#  'mean_rank_filtered_with_test_head': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_head': 1.0,
#  'hits_at_1_filtered_with_test_head': 1.0,
#  'hits_at_3_filtered_with_test_head': 1.0,
#  'hits_at_10_filtered_with_test_head': 1.0,
#  'hits_at_50_filtered_with_test_head': 1.0,
#  'hits_at_100_filtered_with_test_head': 1.0,
#  'hits_at_200_filtered_with_test_head': 1.0,
#  'hits_at_300_filtered_with_test_head': 1.0,
#  'hits_at_400_filtered_with_test_head': 1.0,
#  'hits_at_500_filtered_with_test_head': 1.0,
#  'hits_at_1000_filtered_with_test_head': 1.0,
#  'mean_rank_tail': 6.5,
#  'mean_reciprocal_rank_tail': 0.6076757311820984,
#  'hits_at_1_tail': 0.5,
#  'hits_at_3_tail': 0.625,
#  'hits_at_10_tail': 0.75,
#  'hits_at_50_tail': 1.0,
#  'hits_at_100_tail': 1.0,
#  'hits_at_200_tail': 1.0,
#  'hits_at_300_tail': 1.0,
#  'hits_at_400_tail': 1.0,
#  'hits_at_500_tail': 1.0,
#  'hits_at_1000_tail': 1.0,
#  'mean_rank_filtered_tail': 1.0,
#  'mean_reciprocal_rank_filtered_tail': 1.0,
#  'hits_at_1_filtered_tail': 1.0,
#  'hits_at_3_filtered_tail': 1.0,
#  'hits_at_10_filtered_tail': 1.0,
#  'hits_at_50_filtered_tail': 1.0,
#  'hits_at_100_filtered_tail': 1.0,
#  'hits_at_200_filtered_tail': 1.0,
#  'hits_at_300_filtered_tail': 1.0,
#  'hits_at_400_filtered_tail': 1.0,
#  'hits_at_500_filtered_tail': 1.0,
#  'hits_at_1000_filtered_tail': 1.0,
#  'mean_rank_filtered_with_test_tail': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_tail': 1.0,
#  'hits_at_1_filtered_with_test_tail': 1.0,
#  'hits_at_3_filtered_with_test_tail': 1.0,
#  'hits_at_10_filtered_with_test_tail': 1.0,
#  'hits_at_50_filtered_with_test_tail': 1.0,
#  'hits_at_100_filtered_with_test_tail': 1.0,
#  'hits_at_200_filtered_with_test_tail': 1.0,
#  'hits_at_300_filtered_with_test_tail': 1.0,
#  'hits_at_400_filtered_with_test_tail': 1.0,
#  'hits_at_500_filtered_with_test_tail': 1.0,
#  'hits_at_1000_filtered_with_test_tail': 1.0,
#  'mean_rank_relation': 11.75,
#  'mean_reciprocal_rank_relation': 0.14849288761615753,
#  'hits_at_1_relation': 0.0,
#  'hits_at_3_relation': 0.25,
#  'hits_at_10_relation': 0.5,
#  'hits_at_50_relation': 1.0,
#  'hits_at_100_relation': 1.0,
#  'hits_at_200_relation': 1.0,
#  'hits_at_300_relation': 1.0,
#  'hits_at_400_relation': 1.0,
#  'hits_at_500_relation': 1.0,
#  'hits_at_1000_relation': 1.0,
#  'mean_rank_filtered_relation': 11.25,
#  'mean_reciprocal_rank_filtered_relation': 0.1502944976091385,
#  'hits_at_1_filtered_relation': 0.0,
#  'hits_at_3_filtered_relation': 0.25,
#  'hits_at_10_filtered_relation': 0.5,
#  'hits_at_50_filtered_relation': 1.0,
#  'hits_at_100_filtered_relation': 1.0,
#  'hits_at_200_filtered_relation': 1.0,
#  'hits_at_300_filtered_relation': 1.0,
#  'hits_at_400_filtered_relation': 1.0,
#  'hits_at_500_filtered_relation': 1.0,
#  'hits_at_1000_filtered_relation': 1.0,
#  'mean_rank_filtered_with_test_relation': 11.25,
#  'mean_reciprocal_rank_filtered_with_test_relation': 0.1502944976091385,
#  'hits_at_1_filtered_with_test_relation': 0.0,
#  'hits_at_3_filtered_with_test_relation': 0.25,
#  'hits_at_10_filtered_with_test_relation': 0.5,
#  'hits_at_50_filtered_with_test_relation': 1.0,
#  'hits_at_100_filtered_with_test_relation': 1.0,
#  'hits_at_200_filtered_with_test_relation': 1.0,
#  'hits_at_300_filtered_with_test_relation': 1.0,
#  'hits_at_400_filtered_with_test_relation': 1.0,
#  'hits_at_500_filtered_with_test_relation': 1.0,
#  'hits_at_1000_filtered_with_test_relation': 1.0,
#  'mean_rank_entity': 20.0625,
#  'mean_reciprocal_rank_entity': 0.4678470492362976,
#  'hits_at_1_entity': 0.375,
#  'hits_at_3_entity': 0.5,
#  'hits_at_10_entity': 0.6875,
#  'hits_at_50_entity': 0.8125,
#  'hits_at_100_entity': 1.0,
#  'hits_at_200_entity': 1.0,
#  'hits_at_300_entity': 1.0,
#  'hits_at_400_entity': 1.0,
#  'hits_at_500_entity': 1.0,
#  'hits_at_1000_entity': 1.0,
#  'mean_rank_filtered_entity': 1.0,
#  'mean_reciprocal_rank_filtered_entity': 1.0,
#  'hits_at_1_filtered_entity': 1.0,
#  'hits_at_3_filtered_entity': 1.0,
#  'hits_at_10_filtered_entity': 1.0,
#  'hits_at_50_filtered_entity': 1.0,
#  'hits_at_100_filtered_entity': 1.0,
#  'hits_at_200_filtered_entity': 1.0,
#  'hits_at_300_filtered_entity': 1.0,
#  'hits_at_400_filtered_entity': 1.0,
#  'hits_at_500_filtered_entity': 1.0,
#  'hits_at_1000_filtered_entity': 1.0,
#  'mean_rank_filtered_with_test_entity': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_entity': 1.0,
#  'hits_at_1_filtered_with_test_entity': 1.0,
#  'hits_at_3_filtered_with_test_entity': 1.0,
#  'hits_at_10_filtered_with_test_entity': 1.0,
#  'hits_at_50_filtered_with_test_entity': 1.0,
#  'hits_at_100_filtered_with_test_entity': 1.0,
#  'hits_at_200_filtered_with_test_entity': 1.0,
#  'hits_at_300_filtered_with_test_entity': 1.0,
#  'hits_at_400_filtered_with_test_entity': 1.0,
#  'hits_at_500_filtered_with_test_entity': 1.0,
#  'hits_at_1000_filtered_with_test_entity': 1.0,
#  'mean_rank_M-N': 17.5,
#  'mean_reciprocal_rank_M-N': 0.27754667070176864,
#  'hits_at_1_M-N': 0.16666666666666666,
#  'hits_at_3_M-N': 0.2777777777777778,
#  'hits_at_10_M-N': 0.5555555555555556,
#  'hits_at_50_M-N': 0.8888888888888888,
#  'hits_at_100_M-N': 1.0,
#  'hits_at_200_M-N': 1.0,
#  'hits_at_300_M-N': 1.0,
#  'hits_at_400_M-N': 1.0,
#  'hits_at_500_M-N': 1.0,
#  'hits_at_1000_M-N': 1.0,
#  'mean_rank_filtered_M-N': 5.333333333333333,
#  'mean_reciprocal_rank_filtered_M-N': 0.696427239312066,
#  'hits_at_1_filtered_M-N': 0.6666666666666666,
#  'hits_at_3_filtered_M-N': 0.6666666666666666,
#  'hits_at_10_filtered_M-N': 0.7777777777777778,
#  'hits_at_50_filtered_M-N': 1.0,
#  'hits_at_100_filtered_M-N': 1.0,
#  'hits_at_200_filtered_M-N': 1.0,
#  'hits_at_300_filtered_M-N': 1.0,
#  'hits_at_400_filtered_M-N': 1.0,
#  'hits_at_500_filtered_M-N': 1.0,
#  'hits_at_1000_filtered_M-N': 1.0,
#  'mean_rank_filtered_with_test_M-N': 5.333333333333333,
#  'mean_reciprocal_rank_filtered_with_test_M-N': 0.696427239312066,
#  'hits_at_1_filtered_with_test_M-N': 0.6666666666666666,
#  'hits_at_3_filtered_with_test_M-N': 0.6666666666666666,
#  'hits_at_10_filtered_with_test_M-N': 0.7777777777777778,
#  'hits_at_50_filtered_with_test_M-N': 1.0,
#  'hits_at_100_filtered_with_test_M-N': 1.0,
#  'hits_at_200_filtered_with_test_M-N': 1.0,
#  'hits_at_300_filtered_with_test_M-N': 1.0,
#  'hits_at_400_filtered_with_test_M-N': 1.0,
#  'hits_at_500_filtered_with_test_M-N': 1.0,
#  'hits_at_1000_filtered_with_test_M-N': 1.0,
#  'mean_rank_M-N_head': 29.5,
#  'mean_reciprocal_rank_M-N_head': 0.2688596844673157,
#  'hits_at_1_M-N_head': 0.16666666666666666,
#  'hits_at_3_M-N_head': 0.3333333333333333,
#  'hits_at_10_M-N_head': 0.6666666666666666,
#  'hits_at_50_M-N_head': 0.6666666666666666,
#  'hits_at_100_M-N_head': 1.0,
#  'hits_at_200_M-N_head': 1.0,
#  'hits_at_300_M-N_head': 1.0,
#  'hits_at_400_M-N_head': 1.0,
#  'hits_at_500_M-N_head': 1.0,
#  'hits_at_1000_M-N_head': 1.0,
#  'mean_rank_filtered_M-N_head': 1.0,
#  'mean_reciprocal_rank_filtered_M-N_head': 1.0,
#  'hits_at_1_filtered_M-N_head': 1.0,
#  'hits_at_3_filtered_M-N_head': 1.0,
#  'hits_at_10_filtered_M-N_head': 1.0,
#  'hits_at_50_filtered_M-N_head': 1.0,
#  'hits_at_100_filtered_M-N_head': 1.0,
#  'hits_at_200_filtered_M-N_head': 1.0,
#  'hits_at_300_filtered_M-N_head': 1.0,
#  'hits_at_400_filtered_M-N_head': 1.0,
# ...
#  'hits_at_10_1-N_head': 1.0,
#  'hits_at_50_1-N_head': 1.0,
#  'hits_at_100_1-N_head': 1.0,
#  'hits_at_200_1-N_head': 1.0,
#  'hits_at_300_1-N_head': 1.0,
#  'hits_at_400_1-N_head': 1.0,
#  'hits_at_500_1-N_head': 1.0,
#  'hits_at_1000_1-N_head': 1.0,
#  'mean_rank_filtered_1-N_head': 1.0,
#  'mean_reciprocal_rank_filtered_1-N_head': 1.0,
#  'hits_at_1_filtered_1-N_head': 1.0,
#  'hits_at_3_filtered_1-N_head': 1.0,
#  'hits_at_10_filtered_1-N_head': 1.0,
#  'hits_at_50_filtered_1-N_head': 1.0,
#  'hits_at_100_filtered_1-N_head': 1.0,
#  'hits_at_200_filtered_1-N_head': 1.0,
#  'hits_at_300_filtered_1-N_head': 1.0,
#  'hits_at_400_filtered_1-N_head': 1.0,
#  'hits_at_500_filtered_1-N_head': 1.0,
#  'hits_at_1000_filtered_1-N_head': 1.0,
#  'mean_rank_filtered_with_test_1-N_head': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_1-N_head': 1.0,
#  'hits_at_1_filtered_with_test_1-N_head': 1.0,
#  'hits_at_3_filtered_with_test_1-N_head': 1.0,
#  'hits_at_10_filtered_with_test_1-N_head': 1.0,
#  'hits_at_50_filtered_with_test_1-N_head': 1.0,
#  'hits_at_100_filtered_with_test_1-N_head': 1.0,
#  'hits_at_200_filtered_with_test_1-N_head': 1.0,
#  'hits_at_300_filtered_with_test_1-N_head': 1.0,
#  'hits_at_400_filtered_with_test_1-N_head': 1.0,
#  'hits_at_500_filtered_with_test_1-N_head': 1.0,
#  'hits_at_1000_filtered_with_test_1-N_head': 1.0,
#  'mean_rank_1-N_tail': 1.0,
#  'mean_reciprocal_rank_1-N_tail': 1.0,
#  'hits_at_1_1-N_tail': 1.0,
#  'hits_at_3_1-N_tail': 1.0,
#  'hits_at_10_1-N_tail': 1.0,
#  'hits_at_50_1-N_tail': 1.0,
#  'hits_at_100_1-N_tail': 1.0,
#  'hits_at_200_1-N_tail': 1.0,
#  'hits_at_300_1-N_tail': 1.0,
#  'hits_at_400_1-N_tail': 1.0,
#  'hits_at_500_1-N_tail': 1.0,
#  'hits_at_1000_1-N_tail': 1.0,
#  'mean_rank_filtered_1-N_tail': 1.0,
#  'mean_reciprocal_rank_filtered_1-N_tail': 1.0,
#  'hits_at_1_filtered_1-N_tail': 1.0,
#  'hits_at_3_filtered_1-N_tail': 1.0,
#  'hits_at_10_filtered_1-N_tail': 1.0,
#  'hits_at_50_filtered_1-N_tail': 1.0,
#  'hits_at_100_filtered_1-N_tail': 1.0,
#  'hits_at_200_filtered_1-N_tail': 1.0,
#  'hits_at_300_filtered_1-N_tail': 1.0,
#  'hits_at_400_filtered_1-N_tail': 1.0,
#  'hits_at_500_filtered_1-N_tail': 1.0,
#  'hits_at_1000_filtered_1-N_tail': 1.0,
#  'mean_rank_filtered_with_test_1-N_tail': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_1_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_3_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_10_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_50_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_100_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_200_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_300_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_400_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_500_filtered_with_test_1-N_tail': 1.0,
#  'hits_at_1000_filtered_with_test_1-N_tail': 1.0,
#  'mean_rank_1-N_relation': 3.0,
#  'mean_reciprocal_rank_1-N_relation': 0.3333333432674408,
#  'hits_at_1_1-N_relation': 0.0,
#  'hits_at_3_1-N_relation': 1.0,
#  'hits_at_10_1-N_relation': 1.0,
#  'hits_at_50_1-N_relation': 1.0,
#  'hits_at_100_1-N_relation': 1.0,
#  'hits_at_200_1-N_relation': 1.0,
#  'hits_at_300_1-N_relation': 1.0,
#  'hits_at_400_1-N_relation': 1.0,
#  'hits_at_500_1-N_relation': 1.0,
#  'hits_at_1000_1-N_relation': 1.0,
#  'mean_rank_filtered_1-N_relation': 3.0,
#  'mean_reciprocal_rank_filtered_1-N_relation': 0.3333333432674408,
#  'hits_at_1_filtered_1-N_relation': 0.0,
#  'hits_at_3_filtered_1-N_relation': 1.0,
#  'hits_at_10_filtered_1-N_relation': 1.0,
#  'hits_at_50_filtered_1-N_relation': 1.0,
#  'hits_at_100_filtered_1-N_relation': 1.0,
#  'hits_at_200_filtered_1-N_relation': 1.0,
#  'hits_at_300_filtered_1-N_relation': 1.0,
#  'hits_at_400_filtered_1-N_relation': 1.0,
#  'hits_at_500_filtered_1-N_relation': 1.0,
#  'hits_at_1000_filtered_1-N_relation': 1.0,
#  'mean_rank_filtered_with_test_1-N_relation': 3.0,
#  'mean_reciprocal_rank_filtered_with_test_1-N_relation': 0.3333333432674408,
#  'hits_at_1_filtered_with_test_1-N_relation': 0.0,
#  'hits_at_3_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_10_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_50_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_100_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_200_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_300_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_400_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_500_filtered_with_test_1-N_relation': 1.0,
#  'hits_at_1000_filtered_with_test_1-N_relation': 1.0,
#  'mean_rank_M-1': 31.666666666666668,
#  'mean_reciprocal_rank_M-1': 0.44810744126637775,
#  'hits_at_1_M-1': 0.3333333333333333,
#  'hits_at_3_M-1': 0.6666666666666666,
#  'hits_at_10_M-1': 0.6666666666666666,
#  'hits_at_50_M-1': 0.6666666666666666,
#  'hits_at_100_M-1': 1.0,
#  'hits_at_200_M-1': 1.0,
#  'hits_at_300_M-1': 1.0,
#  'hits_at_400_M-1': 1.0,
#  'hits_at_500_M-1': 1.0,
#  'hits_at_1000_M-1': 1.0,
#  'mean_rank_filtered_M-1': 1.6666666666666667,
#  'mean_reciprocal_rank_filtered_M-1': 0.7777777512868246,
#  'hits_at_1_filtered_M-1': 0.6666666666666666,
#  'hits_at_3_filtered_M-1': 1.0,
#  'hits_at_10_filtered_M-1': 1.0,
#  'hits_at_50_filtered_M-1': 1.0,
#  'hits_at_100_filtered_M-1': 1.0,
#  'hits_at_200_filtered_M-1': 1.0,
#  'hits_at_300_filtered_M-1': 1.0,
#  'hits_at_400_filtered_M-1': 1.0,
#  'hits_at_500_filtered_M-1': 1.0,
#  'hits_at_1000_filtered_M-1': 1.0,
#  'mean_rank_filtered_with_test_M-1': 1.6666666666666667,
#  'mean_reciprocal_rank_filtered_with_test_M-1': 0.7777777512868246,
#  'hits_at_1_filtered_with_test_M-1': 0.6666666666666666,
#  'hits_at_3_filtered_with_test_M-1': 1.0,
#  'hits_at_10_filtered_with_test_M-1': 1.0,
#  'hits_at_50_filtered_with_test_M-1': 1.0,
#  'hits_at_100_filtered_with_test_M-1': 1.0,
#  'hits_at_200_filtered_with_test_M-1': 1.0,
#  'hits_at_300_filtered_with_test_M-1': 1.0,
#  'hits_at_400_filtered_with_test_M-1': 1.0,
#  'hits_at_500_filtered_with_test_M-1': 1.0,
#  'hits_at_1000_filtered_with_test_M-1': 1.0,
#  'mean_rank_M-1_head': 91.0,
#  'mean_reciprocal_rank_M-1_head': 0.010989011265337467,
#  'hits_at_1_M-1_head': 0.0,
#  'hits_at_3_M-1_head': 0.0,
#  'hits_at_10_M-1_head': 0.0,
#  'hits_at_50_M-1_head': 0.0,
#  'hits_at_100_M-1_head': 1.0,
#  'hits_at_200_M-1_head': 1.0,
#  'hits_at_300_M-1_head': 1.0,
#  'hits_at_400_M-1_head': 1.0,
#  'hits_at_500_M-1_head': 1.0,
#  'hits_at_1000_M-1_head': 1.0,
#  'mean_rank_filtered_M-1_head': 1.0,
#  'mean_reciprocal_rank_filtered_M-1_head': 1.0,
#  'hits_at_1_filtered_M-1_head': 1.0,
#  'hits_at_3_filtered_M-1_head': 1.0,
#  'hits_at_10_filtered_M-1_head': 1.0,
#  'hits_at_50_filtered_M-1_head': 1.0,
#  'hits_at_100_filtered_M-1_head': 1.0,
#  'hits_at_200_filtered_M-1_head': 1.0,
#  'hits_at_300_filtered_M-1_head': 1.0,
#  'hits_at_400_filtered_M-1_head': 1.0,
#  'hits_at_500_filtered_M-1_head': 1.0,
#  'hits_at_1000_filtered_M-1_head': 1.0,
#  'mean_rank_filtered_with_test_M-1_head': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_M-1_head': 1.0,
#  'hits_at_1_filtered_with_test_M-1_head': 1.0,
#  'hits_at_3_filtered_with_test_M-1_head': 1.0,
#  'hits_at_10_filtered_with_test_M-1_head': 1.0,
#  'hits_at_50_filtered_with_test_M-1_head': 1.0,
#  'hits_at_100_filtered_with_test_M-1_head': 1.0,
#  'hits_at_200_filtered_with_test_M-1_head': 1.0,
#  'hits_at_300_filtered_with_test_M-1_head': 1.0,
#  'hits_at_400_filtered_with_test_M-1_head': 1.0,
#  'hits_at_500_filtered_with_test_M-1_head': 1.0,
#  'hits_at_1000_filtered_with_test_M-1_head': 1.0,
#  'mean_rank_M-1_tail': 1.0,
#  'mean_reciprocal_rank_M-1_tail': 1.0,
#  'hits_at_1_M-1_tail': 1.0,
#  'hits_at_3_M-1_tail': 1.0,
#  'hits_at_10_M-1_tail': 1.0,
#  'hits_at_50_M-1_tail': 1.0,
#  'hits_at_100_M-1_tail': 1.0,
#  'hits_at_200_M-1_tail': 1.0,
#  'hits_at_300_M-1_tail': 1.0,
#  'hits_at_400_M-1_tail': 1.0,
#  'hits_at_500_M-1_tail': 1.0,
#  'hits_at_1000_M-1_tail': 1.0,
#  'mean_rank_filtered_M-1_tail': 1.0,
#  'mean_reciprocal_rank_filtered_M-1_tail': 1.0,
#  'hits_at_1_filtered_M-1_tail': 1.0,
#  'hits_at_3_filtered_M-1_tail': 1.0,
#  'hits_at_10_filtered_M-1_tail': 1.0,
#  'hits_at_50_filtered_M-1_tail': 1.0,
#  'hits_at_100_filtered_M-1_tail': 1.0,
#  'hits_at_200_filtered_M-1_tail': 1.0,
#  'hits_at_300_filtered_M-1_tail': 1.0,
#  'hits_at_400_filtered_M-1_tail': 1.0,
#  'hits_at_500_filtered_M-1_tail': 1.0,
#  'hits_at_1000_filtered_M-1_tail': 1.0,
#  'mean_rank_filtered_with_test_M-1_tail': 1.0,
#  'mean_reciprocal_rank_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_1_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_3_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_10_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_50_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_100_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_200_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_300_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_400_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_500_filtered_with_test_M-1_tail': 1.0,
#  'hits_at_1000_filtered_with_test_M-1_tail': 1.0,
#  'mean_rank_M-1_relation': 3.0,
#  'mean_reciprocal_rank_M-1_relation': 0.3333333432674408,
#  'hits_at_1_M-1_relation': 0.0,
#  'hits_at_3_M-1_relation': 1.0,
#  'hits_at_10_M-1_relation': 1.0,
#  'hits_at_50_M-1_relation': 1.0,
#  'hits_at_100_M-1_relation': 1.0,
#  'hits_at_200_M-1_relation': 1.0,
#  'hits_at_300_M-1_relation': 1.0,
#  'hits_at_400_M-1_relation': 1.0,
#  'hits_at_500_M-1_relation': 1.0,
#  'hits_at_1000_M-1_relation': 1.0,
#  'mean_rank_filtered_M-1_relation': 3.0,
#  'mean_reciprocal_rank_filtered_M-1_relation': 0.3333333432674408,
#  'hits_at_1_filtered_M-1_relation': 0.0,
#  'hits_at_3_filtered_M-1_relation': 1.0,
#  'hits_at_10_filtered_M-1_relation': 1.0,
#  'hits_at_50_filtered_M-1_relation': 1.0,
#  'hits_at_100_filtered_M-1_relation': 1.0,
#  'hits_at_200_filtered_M-1_relation': 1.0,
#  'hits_at_300_filtered_M-1_relation': 1.0,
#  'hits_at_400_filtered_M-1_relation': 1.0,
#  'hits_at_500_filtered_M-1_relation': 1.0,
#  'hits_at_1000_filtered_M-1_relation': 1.0,
#  'mean_rank_filtered_with_test_M-1_relation': 3.0,
#  'mean_reciprocal_rank_filtered_with_test_M-1_relation': 0.3333333432674408,
#  'hits_at_1_filtered_with_test_M-1_relation': 0.0,
#  'hits_at_3_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_10_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_50_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_100_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_200_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_300_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_400_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_500_filtered_with_test_M-1_relation': 1.0,
#  'hits_at_1000_filtered_with_test_M-1_relation': 1.0,
#  'mean_rank_1-1': 0.0,
#  'mean_reciprocal_rank_1-1': 0.0,
#  'hits_at_1_1-1': 0.0,
#  'hits_at_3_1-1': 0.0,
#  'hits_at_10_1-1': 0.0,
#  'hits_at_50_1-1': 0.0,
#  'hits_at_100_1-1': 0.0,
#  'hits_at_200_1-1': 0.0,
#  'hits_at_300_1-1': 0.0,
#  'hits_at_400_1-1': 0.0,
#  'hits_at_500_1-1': 0.0,
#  'hits_at_1000_1-1': 0.0,
#  'mean_rank_filtered_1-1': 0.0,
#  'mean_reciprocal_rank_filtered_1-1': 0.0,
#  'hits_at_1_filtered_1-1': 0.0,
#  'hits_at_3_filtered_1-1': 0.0,
#  'hits_at_10_filtered_1-1': 0.0,
#  'hits_at_50_filtered_1-1': 0.0,
#  'hits_at_100_filtered_1-1': 0.0,
#  'hits_at_200_filtered_1-1': 0.0,
#  'hits_at_300_filtered_1-1': 0.0,
#  'hits_at_400_filtered_1-1': 0.0,
#  'hits_at_500_filtered_1-1': 0.0,
#  'hits_at_1000_filtered_1-1': 0.0,
#  'mean_rank_filtered_with_test_1-1': 0.0,
#  'mean_reciprocal_rank_filtered_with_test_1-1': 0.0,
#  'hits_at_1_filtered_with_test_1-1': 0.0,
#  'hits_at_3_filtered_with_test_1-1': 0.0,
#  'hits_at_10_filtered_with_test_1-1': 0.0,
#  'hits_at_50_filtered_with_test_1-1': 0.0,
#  'hits_at_100_filtered_with_test_1-1': 0.0,
#  'hits_at_200_filtered_with_test_1-1': 0.0,
#  'hits_at_300_filtered_with_test_1-1': 0.0,
#  'hits_at_400_filtered_with_test_1-1': 0.0,
#  'hits_at_500_filtered_with_test_1-1': 0.0,
#  'hits_at_1000_filtered_with_test_1-1': 0.0,
#  'mean_rank_1-1_head': 0.0,
#  'mean_reciprocal_rank_1-1_head': 0.0,
#  'hits_at_1_1-1_head': 0.0,
#  'hits_at_3_1-1_head': 0.0,
#  'hits_at_10_1-1_head': 0.0,
#  'hits_at_50_1-1_head': 0.0,
#  'hits_at_100_1-1_head': 0.0,
#  'hits_at_200_1-1_head': 0.0,
#  'hits_at_300_1-1_head': 0.0,
#  'hits_at_400_1-1_head': 0.0,
#  'hits_at_500_1-1_head': 0.0,
#  'hits_at_1000_1-1_head': 0.0,
#  'mean_rank_filtered_1-1_head': 0.0,
#  'mean_reciprocal_rank_filtered_1-1_head': 0.0,
#  'hits_at_1_filtered_1-1_head': 0.0,
#  'hits_at_3_filtered_1-1_head': 0.0,
#  'hits_at_10_filtered_1-1_head': 0.0,
#  'hits_at_50_filtered_1-1_head': 0.0,
#  'hits_at_100_filtered_1-1_head': 0.0,
#  'hits_at_200_filtered_1-1_head': 0.0,
#  'hits_at_300_filtered_1-1_head': 0.0,
#  'hits_at_400_filtered_1-1_head': 0.0,
#  'hits_at_500_filtered_1-1_head': 0.0,
#  'hits_at_1000_filtered_1-1_head': 0.0,
#  'mean_rank_filtered_with_test_1-1_head': 0.0,
#  'mean_reciprocal_rank_filtered_with_test_1-1_head': 0.0,
#  'hits_at_1_filtered_with_test_1-1_head': 0.0,
#  'hits_at_3_filtered_with_test_1-1_head': 0.0,
#  'hits_at_10_filtered_with_test_1-1_head': 0.0,
#  'hits_at_50_filtered_with_test_1-1_head': 0.0,
#  'hits_at_100_filtered_with_test_1-1_head': 0.0,
#  'hits_at_200_filtered_with_test_1-1_head': 0.0,
#  'hits_at_300_filtered_with_test_1-1_head': 0.0,
#  'hits_at_400_filtered_with_test_1-1_head': 0.0,
#  'hits_at_500_filtered_with_test_1-1_head': 0.0,
#  'hits_at_1000_filtered_with_test_1-1_head': 0.0,
#  'mean_rank_1-1_tail': 0.0,
#  'mean_reciprocal_rank_1-1_tail': 0.0,
#  'hits_at_1_1-1_tail': 0.0,
#  'hits_at_3_1-1_tail': 0.0,
#  'hits_at_10_1-1_tail': 0.0,
#  'hits_at_50_1-1_tail': 0.0,
#  'hits_at_100_1-1_tail': 0.0,
#  'hits_at_200_1-1_tail': 0.0,
#  'hits_at_300_1-1_tail': 0.0,
#  'hits_at_400_1-1_tail': 0.0,
#  'hits_at_500_1-1_tail': 0.0,
#  'hits_at_1000_1-1_tail': 0.0,
#  'mean_rank_filtered_1-1_tail': 0.0,
#  'mean_reciprocal_rank_filtered_1-1_tail': 0.0,
#  'hits_at_1_filtered_1-1_tail': 0.0,
#  'hits_at_3_filtered_1-1_tail': 0.0,
#  'hits_at_10_filtered_1-1_tail': 0.0,
#  'hits_at_50_filtered_1-1_tail': 0.0,
#  'hits_at_100_filtered_1-1_tail': 0.0,
#  'hits_at_200_filtered_1-1_tail': 0.0,
#  'hits_at_300_filtered_1-1_tail': 0.0,
#  'hits_at_400_filtered_1-1_tail': 0.0,
#  'hits_at_500_filtered_1-1_tail': 0.0,
#  'hits_at_1000_filtered_1-1_tail': 0.0,
#  'mean_rank_filtered_with_test_1-1_tail': 0.0,
#  'mean_reciprocal_rank_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_1_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_3_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_10_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_50_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_100_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_200_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_300_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_400_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_500_filtered_with_test_1-1_tail': 0.0,
#  'hits_at_1000_filtered_with_test_1-1_tail': 0.0,
#  'mean_rank_1-1_relation': 0.0,
#  'mean_reciprocal_rank_1-1_relation': 0.0,
#  'hits_at_1_1-1_relation': 0.0,
#  'hits_at_3_1-1_relation': 0.0,
#  'hits_at_10_1-1_relation': 0.0,
#  'hits_at_50_1-1_relation': 0.0,
#  'hits_at_100_1-1_relation': 0.0,
#  'hits_at_200_1-1_relation': 0.0,
#  'hits_at_300_1-1_relation': 0.0,
#  'hits_at_400_1-1_relation': 0.0,
#  'hits_at_500_1-1_relation': 0.0,
#  'hits_at_1000_1-1_relation': 0.0,
#  'mean_rank_filtered_1-1_relation': 0.0,
#  'mean_reciprocal_rank_filtered_1-1_relation': 0.0,
#  'hits_at_1_filtered_1-1_relation': 0.0,
#  'hits_at_3_filtered_1-1_relation': 0.0,
#  'hits_at_10_filtered_1-1_relation': 0.0,
#  'hits_at_50_filtered_1-1_relation': 0.0,
#  'hits_at_100_filtered_1-1_relation': 0.0,
#  'hits_at_200_filtered_1-1_relation': 0.0,
#  'hits_at_300_filtered_1-1_relation': 0.0,
#  'hits_at_400_filtered_1-1_relation': 0.0,
#  'hits_at_500_filtered_1-1_relation': 0.0,
#  'hits_at_1000_filtered_1-1_relation': 0.0,
#  'mean_rank_filtered_with_test_1-1_relation': 0.0,
#  'mean_reciprocal_rank_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_1_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_3_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_10_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_50_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_100_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_200_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_300_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_400_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_500_filtered_with_test_1-1_relation': 0.0,
#  'hits_at_1000_filtered_with_test_1-1_relation': 0.0,
#  'num_parameters': 7687680,
#  'timestamp': 1655895991.7743285,
#  'entry_id': '92c67175-affa-48bf-ae62-e25b5d3d7a46'}

# %%
eval.all_ranks
# Out:
# {'sp_to_o': tensor([ 3,  0, 12, 28,  0,  1,  0]),
#  'po_to_s': tensor([ 6, 90,  8,  2, 68, 87,  0]),
#  'so_to_p': tensor([ 4,  1,  5,  6, 28, 16,  6])}

# %%
eval.all_ranks_filt
# Out:
# {'sp_to_o': tensor([0, 0, 0, 0, 0, 0, 0]),
#  'po_to_s': tensor([0, 0, 0, 0, 0, 0, 0]),
#  'so_to_p': tensor([ 4,  1,  5,  6, 27, 14,  5])}

# %%
valid_data[[17, 18, 19, 20, 136, 20451, 12366]]
# Out:
# tensor([[  34,    6,   35],
#         [  36,   16,   32],
#         [  37,    8,   38],
#         [  39,    7,   40],
#         [ 248,   66,  249],
#         [1798,   66, 1327],
#         [1798,   45, 4657]], dtype=torch.int32)

# %%
print(model.dataset.entity_strings(torch.Tensor([1798]).long()))
print(model.dataset.relation_strings(torch.Tensor([66]).long()))
print(model.dataset.entity_strings(torch.Tensor([1327]).long()))
# Out:
# ['Zooey Deschanel']
# ['/people/person/places_lived./people/place_lived/location']
# ['Los Angeles']

# %%
list(predicted_o_score)
# Out:
# [[15.832500457763672,
#   15.68239974975586,
#   15.575333595275879,
#   15.557999610900879,
#   15.478597640991211,
#   15.47299861907959,
#   15.407565116882324,
#   15.392574310302734,
#   15.387632369995117,
#   15.363303184509277,
#   15.304561614990234,
#   15.169096946716309,
#   12.692606925964355,
#   12.482621192932129,
#   12.355673789978027]]
