# %%
from collections import Counter

import pandas as pd
import torch
from kge.job.eval import EvaluationJob
from kge.model import KgeModel
from kge.util.io import load_checkpoint
from functools import reduce

PATH = "/work/dhuynh/Workspaces/Thesis/kge/local/experiments/error_analysis"

checkpoint = load_checkpoint(f'{PATH}/best_models/ICLR20/ComplEx/FB237/Hybrid_hybrid/checkpoint_best.pt')
model = KgeModel.create_from(checkpoint)

# load data
model.dataset.relation_strings(torch.Tensor([1,]).long())
model.dataset.entity_strings(torch.Tensor([1,]).long())

relation_embedder = model.get_p_embedder()
meta_relation = model.dataset._meta['relation_strings']
meta_entity = model.dataset._meta['entity_strings']
# Out:
# Loading configuration of dataset fb15k-237 from /work/dhuynh/Workspaces/Thesis/kge/data/fb15k-237 ...
# Loaded 237 keys from map relation_strings
# Loaded 14541 keys from map entity_ids
# Warning: could not find 8 ids in map entity_strings; filling with None.
# Loaded 14541 keys from map entity_strings

# %%
import pandas as pd

df_ranking_training = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_hybrid_error_analysis_ranking_train.csv')
df_ranking_training['eval_type'] = 'train'
relation_type = df_ranking_training[['name_relation', 'relation_type']].drop_duplicates().set_index('name_relation').to_dict()['relation_type']

df_metric_training = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_hybrid_error_analysis_metric_train.csv')
df_metric_training['eval_type'] = 'train'
df_metric_training = df_metric_training.rename(columns={'relation': 'name_relation'})

df_ranking_training = df_ranking_training.merge(df_metric_training[['name_relation', 
                                                                    'mean_reciprocal_rank_filtered_with_test_relation_standard',
                                                                    'mean_reciprocal_rank_filtered_with_test_relation_hybrid']]\
                                                        .rename(columns={'mean_reciprocal_rank_filtered_with_test_relation_standard': 'MRR_standard',
                                                                        'mean_reciprocal_rank_filtered_with_test_relation_hybrid': 'MRR_hybrid'}),
                                                on='name_relation', how='left')

df_ranking_training.head(2)
# Out:
#    id                 name_subjects  \
# 0   0            Dominican Republic
# 1   1  Mighty Morphin Power Rangers
#
#                                        name_relation name_objects  \
# 0               /location/country/form_of_government     Republic
# 1  /tv/tv_program/regular_cast./tv/regular_tv_app...   Wendee Lee
#
#   relation_type                                            triplet  \
# 0           M-N  Dominican Republic | /location/country/form_of...
# 1           1-N  Mighty Morphin Power Rangers | /tv/tv_program/...
#
#    po_to_s_hybrid  po_to_s_standard  \
# 0               0                 0
# 1               0                 0
#
#                              predicted_object_hybrid  \
# 0  ['Republic' 'Democracy' 'Presidential system' ...
# 1  ['Johnny Yong Bosch' 'Wendee Lee' 'Jeff Bennet...
#
#                       predicted_object_scores_hybrid  ...  \
# 0  [11.245938301086426, 10.739019393920898, 9.936...  ...
# 1  [15.297163009643555, 14.774636268615723, 9.455...  ...
#
#                       predicted_subject_score_hybrid  \
# 0  [11.99709701538086, 11.907685279846191, 11.883...
# 1  [14.774637222290039, 10.309414863586426, 9.181...
#
#                     predicted_subject_score_standard  \
# 0  [12.472025871276855, 12.343207359313965, 12.24...
# 1  [14.661572456359863, 11.222408294677734, 10.83...
#
#                           predicted_subject_standard so_to_p_hybrid  \
# 0  ['Zambia' 'Guinea-Bissau' 'Congo' 'Djibouti' '...              0
# 1  ['Mighty Morphin Power Rangers' 'Ben 10' 'Kid ...              0
#
#   so_to_p_standard sp_to_o_hybrid sp_to_o_standard eval_type  MRR_standard  \
# 0                0              0                0     train      1.000000
# 1                0              0                0     train      0.913981
#
#    MRR_hybrid
# 0         1.0
# 1         1.0
#
# [2 rows x 25 columns]

# %%
df_ranking_validation = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_hybrid_error_analysis_ranking_valid.csv')
df_ranking_validation['eval_type'] = 'valid'
df_ranking_validation.head(2)

df_metric_validation = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_hybrid_error_analysis_metric_valid.csv')
df_metric_validation['eval_type'] = 'valid'
df_metric_validation = df_metric_validation.rename(columns={'relation': 'name_relation'})

df_ranking_validation = df_ranking_validation.merge(df_metric_validation[['name_relation', 
                                                                          'mean_reciprocal_rank_filtered_with_test_relation_standard',
                                                                          'mean_reciprocal_rank_filtered_with_test_relation_hybrid']]\
                                                                  .rename(columns={'mean_reciprocal_rank_filtered_with_test_relation_standard': 'MRR_standard',
                                                                                  'mean_reciprocal_rank_filtered_with_test_relation_hybrid': 'MRR_hybrid'}),
                                                          on='name_relation', how='left')

df_ranking_validation.head(2)
# Out:
#    id name_subjects                  name_relation       name_objects  \
# 0   0  American Pie               /film/film/genre       Romance Film
# 1   1     St. Louis  /location/location/time_zones  Central Time Zone
#
#   relation_type                                            triplet  \
# 0           M-N     American Pie | /film/film/genre | Romance Film
# 1           M-1  St. Louis | /location/location/time_zones | Ce...
#
#    po_to_s_hybrid  po_to_s_standard  \
# 0              75               237
# 1               0                13
#
#                              predicted_object_hybrid  \
# 0  ['Comedy' 'Drama (Film genre) #99' 'Romance Fi...
# 1  ['Central Time Zone' 'Eastern Time Zone' 'Paci...
#
#                       predicted_object_scores_hybrid  ...  \
# 0  [9.811301231384277, 9.581463813781738, 9.44480...  ...
# 1  [10.947417259216309, 10.43017864227295, 7.6015...  ...
#
#                       predicted_subject_score_hybrid  \
# 0  [11.474705696105957, 11.343169212341309, 11.33...
# 1  [12.535480499267578, 12.519914627075195, 12.48...
#
#                     predicted_subject_score_standard  \
# 0  [11.361373901367188, 11.339797973632812, 11.27...
# 1  [12.987507820129395, 12.84952449798584, 12.793...
#
#                           predicted_subject_standard so_to_p_hybrid  \
# 0  ['The Last Song' 'Gigi' 'Shopgirl' 'The Mirror...              0
# 1  ['St. Cloud' 'Tarrant County' 'Norman' 'Bexar ...              0
#
#   so_to_p_standard sp_to_o_hybrid sp_to_o_standard eval_type  MRR_standard  \
# 0                0              1                1     valid      0.990018
# 1                0              0                1     valid      0.978036
#
#    MRR_hybrid
# 0    0.994335
# 1    1.000000
#
# [2 rows x 25 columns]

# %%
df_relation_similarity = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_error_analysis_relation_similarity.csv')
df_relation_similarity
# Out:
#                                            pair_relation  \
# 0      /american_football/football_team/current_roste...
# 1      /american_football/football_team/current_roste...
# 2      /american_football/football_team/current_roste...
# 3      /american_football/football_team/current_roste...
# 4      /american_football/football_team/current_roste...
# ...                                                  ...
# 27961  /user/tsegaran/random/taxonomy_subject/entry./...
# 27962  /user/tsegaran/random/taxonomy_subject/entry./...
# 27963  /user/tsegaran/random/taxonomy_subject/entry./...
# 27964  /user/tsegaran/random/taxonomy_subject/entry./...
# 27965  /user/tsegaran/random/taxonomy_subject/entry./...
#
#        cosine_sim_standard_Hybrid  cosine_sim_standard_ER  \
# 0                       -0.104892                0.092078
# 1                        0.064897                0.023882
# 2                        0.014647               -0.013251
# 3                       -0.056359                0.055919
# 4                        0.024058               -0.025661
# ...                           ...                     ...
# 27961                   -0.005677               -0.072310
# 27962                    0.052820               -0.002278
# 27963                   -0.069270               -0.032342
# 27964                    0.030504                0.041609
# 27965                   -0.084874               -0.046478
#
#        cosine_sim_hybrid_Hybrid  cosine_sim_hybrid_ER
# 0                      0.130913             -0.017204
# 1                      0.410136              0.098994
# 2                      0.367712              0.103778
# 3                      0.253017              0.137882
# 4                      0.388793              0.186660
# ...                         ...                   ...
# 27961                  0.354967              0.080502
# 27962                  0.236273              0.041826
# 27963                  0.119281              0.036081
# 27964                  0.289697              0.048771
# 27965                  0.353565              0.049785
#
# [27966 rows x 5 columns]

# %%
import ast
df_similar_so = pd.read_csv('results/ICLR20/ComplEx/FB237/fb237_error_analysis_relations_in_similar_so_all.csv')
df_similar_so['name_relation'] = df_similar_so.name_relation.map(lambda x: ast.literal_eval(x))
df_similar_so.head(2)
# Out:
#                                              so_pair  \
# 0  (500) Days of Summer, _ ,2009 Sundance Film Fe...
# 1            (500) Days of Summer, _ ,United Kingdom
#
#                                        name_relation eval_type  \
# 0  (/film/film/film_festivals, /film/film/release...     train
# 1  (/film/film/distributors./film/film_film_distr...     train
#
#     relation_type        counts  is_similar so_to_p_standard_Hybrid  \
# 0  ('M-1', 'M-1')    (280, 262)        True                  (0, 0)
# 1  ('M-1', 'M-N')  (168, 14121)       False                  (0, 1)
#
#   so_to_p_standard_ER so_to_p_hybrid_Hybrid so_to_p_hybrid_ER  ...  \
# 0              (2, 1)                (0, 0)            (0, 0)  ...
# 1             (6, 12)                (0, 0)            (0, 0)  ...
#
#                     predicted_relation_hybrid_Hybrid  \
# 0  /film/film/release_date_s./film/film_regional_...
# 1  /film/film/release_date_s./film/film_regional_...
#
#                         predicted_relation_hybrid_ER  \
# 0                          /film/film/film_festivals
# 1  /film/film/release_date_s./film/film_regional_...
#
#   euclidean_dist_standard_Hybrid euclidean_dist_standard_ER  \
# 0                      13.807630                   3.476251
# 1                      13.493464                   4.926343
#
#    euclidean_dist_hybrid_Hybrid  euclidean_dist_hybrid_ER  \
# 0                     12.885740                 10.733234
# 1                     15.633004                 15.075353
#
#    cosine_sim_standard_Hybrid  cosine_sim_standard_ER  \
# 0                    0.727376                0.525105
# 1                    0.601617                0.199831
#
#    cosine_sim_hybrid_Hybrid  cosine_sim_hybrid_ER
# 0                  0.663774              0.627073
# 1                  0.232598              0.229358
#
# [2 rows x 22 columns]

# %%
list_relation_in_so = list(set(sum(df_similar_so.name_relation.unique(), ())))
list_relation_in_so[:3]
# Out:
# ['/organization/organization/place_founded',
#  '/music/group_member/membership./music/group_membership/group',
#  '/people/ethnicity/geographic_distribution']

# %%
import numpy as np
import ast
import re

def get_list_relation(relations):
    output = tuple(ast.literal_eval(re.sub(r"'\n '", "', '", re.sub(r"' '", "', '", relations))))
    if len(output) != 3 or output == None:
        print(relations)
        print(re.sub(r"'\n '", "', '", re.sub(r"' '", "', '", relations)))
        print(output)
        raise ValueError('wrong number of relations')
    return output

relation_type = df_ranking_training[['name_relation', 'relation_type']].drop_duplicates().set_index('name_relation').to_dict()['relation_type']

def get_relation_type(relations_tuple):
    output = []
    try:
        for rel in relations_tuple:
            output.append(relation_type[rel])
    except Exception:
        print('relations_tuple', relations_tuple)
        raise ValueError('wrong number of relations')
    return tuple(output)

subjects_objects_of_relations_train = {}
for relation in df_ranking_training.name_relation.unique():
    subjects_objects_of_relations_train[relation] = {
        'subjects': set(df_ranking_training[df_ranking_training.name_relation == relation].name_subjects),
        'objects': set(df_ranking_training[df_ranking_training.name_relation == relation].name_objects)
    }
    

def get_jaccard_sim(relation_pair, target):
    list_sets = []
    for rel in relation_pair:        
        list_sets.append(subjects_objects_of_relations_train[rel][target])
    def jaccard_similarity(set_1, set_2):
        return np.maximum(np.round(len(set_1.intersection(set_2)) / len(set_1.union(set_2)), 2), 0.00001)
    return jaccard_similarity(list_sets[0], list_sets[1])

def get_jaccard_sim_top3(row, origin, target):
    output = []
    relations = row[origin]
    name_relation = row.name_relation
    # print(df.head(2))
    for relation in relations:
        tmp = get_jaccard_sim((name_relation, relation), target)
        output.append(tmp)
    return tuple(output)

def harmonic_mean(x):
    return len(x) / sum(1 / i for i in x)

# %% [markdown]
# # Standard Model selected on hybrid MRR (Baseline model)

# %%
columns = ['name_subjects', 'name_relation', 'name_objects', 'relation_type', 'eval_type',
           'predicted_relation_hybrid', 'so_to_p_hybrid', 'MRR_hybrid',]
df_std_hybrid_ranking = pd.concat([df_ranking_training[columns].copy(), df_ranking_validation[columns].copy()])

df_std_hybrid_ranking['predicted_relation_hybrid'] = df_std_hybrid_ranking['predicted_relation_hybrid'].map(lambda x: get_list_relation(x))
df_std_hybrid_ranking['predicted_relation_type_hybrid'] = df_std_hybrid_ranking['predicted_relation_hybrid'].map(lambda x: get_relation_type(x))

df_std_hybrid_ranking.tail(2)
# Out:
#       name_subjects                                      name_relation  \
# 17533         50/50  /film/film/release_date_s./film/film_regional_...
# 17534  Selena Gomez            /film/actor/film./film/performance/film
#
#              name_objects relation_type eval_type  \
# 17533           Singapore           M-N     valid
# 17534  Hotel Transylvania           M-N     valid
#
#                                predicted_relation_hybrid  so_to_p_hybrid  \
# 17533  (/film/film/release_date_s./film/film_regional...               0
# 17534  (/organization/organization/headquarters./loca...               1
#
#        MRR_hybrid predicted_relation_type_hybrid
# 17533    0.989023                (M-N, M-1, M-1)
# 17534    0.967295                (M-1, M-N, 1-N)

# %%
get_jaccard_sim(('/people/person/places_lived./people/place_lived/location','/people/person/place_of_birth'), 'subjects')
get_jaccard_sim(('/people/person/places_lived./people/place_lived/location','/people/person/place_of_birth'), 'objects')
# Out:
# 0.49

# %%
import seaborn as sns
result_objects = df_std_hybrid_ranking[['name_relation', 'relation_type', 'predicted_relation_hybrid', 'eval_type', 'MRR_hybrid']].copy()
result_objects['ranks'] = result_objects.apply(lambda row: get_jaccard_sim_top3(row, 'predicted_relation_hybrid', 'objects'), axis=1)
result_objects[['First rank', 'Second rank', 'Third rank']] = pd.DataFrame(result_objects['ranks'].tolist(), index=result_objects.index)
result_objects = result_objects.drop(['ranks'], axis=1)
result_objects_plt = result_objects.groupby(['name_relation', 'relation_type', 'eval_type']).mean().reset_index()\
    .melt(id_vars=['name_relation', 'relation_type', 'eval_type', 'MRR_hybrid'], 
          value_vars=['First rank', 'Second rank', 'Third rank'], 
          var_name='rank', value_name='jaccard_sim')
result_objects_plt
result_subjects = df_std_hybrid_ranking[['name_relation', 'relation_type', 'predicted_relation_hybrid', 'eval_type', 'MRR_hybrid']].copy()
result_subjects['ranks'] = result_subjects.apply(lambda row: get_jaccard_sim_top3(row, 'predicted_relation_hybrid', 'subjects'), axis=1)
result_subjects[['First rank', 'Second rank', 'Third rank']] = pd.DataFrame(result_subjects['ranks'].tolist(), index=result_subjects.index)
result_subjects = result_subjects.drop(['ranks'], axis=1)
result_subjects_plt = result_subjects.groupby(['name_relation', 'relation_type', 'eval_type']).mean().reset_index()\
    .melt(id_vars=['name_relation', 'relation_type', 'eval_type', 'MRR_hybrid'], 
          value_vars=['First rank', 'Second rank', 'Third rank'], 
          var_name='rank', value_name='jaccard_sim')

result_objects_plt['target'] = 'objects'
result_subjects_plt['target'] = 'subjects'
result_subjects_plt
# Out:
#                                           name_relation relation_type  \
# 0     /american_football/football_team/current_roste...           M-N
# 1     /american_football/football_team/current_roste...           M-N
# 2                     /award/award_category/category_of           M-1
# 3                     /award/award_category/category_of           M-1
# 4         /award/award_category/disciplines_or_subjects           M-N
# ...                                                 ...           ...
# 1375       /user/jg/default_domain/olympic_games/sports           M-N
# 1376  /user/ktrueman/default_domain/international_or...           1-N
# 1377  /user/ktrueman/default_domain/international_or...           1-N
# 1378  /user/tsegaran/random/taxonomy_subject/entry./...           M-1
# 1379  /user/tsegaran/random/taxonomy_subject/entry./...           M-1
#
#      eval_type  MRR_hybrid        rank  jaccard_sim    target
# 0        train    1.000000  First rank     1.000000  subjects
# 1        valid    0.500000  First rank     0.970000  subjects
# 2        train    1.000000  First rank     1.000000  subjects
# 3        valid    0.925729  First rank     0.923078  subjects
# 4        train    1.000000  First rank     1.000000  subjects
# ...        ...         ...         ...          ...       ...
# 1375     valid    1.000000  Third rank     0.021437  subjects
# 1376     train    1.000000  Third rank     0.000010  subjects
# 1377     valid    1.000000  Third rank     0.000010  subjects
# 1378     train    1.000000  Third rank     0.033243  subjects
# 1379     valid    0.953947  Third rank     0.012509  subjects
#
# [1380 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

sthg_fun = result_objects_plt.copy()
sthg_fun['type'] = sthg_fun.name_relation.map(lambda x: 'Domain-sharing' if x in list_relation_in_so else 'Non domain-sharing')
sthg_fun['eval_type'] = sthg_fun.eval_type.map(lambda x: x.capitalize())
sthg_fun_2 = sthg_fun.copy()
sthg_fun_2['type'] = 'Both'

plt.figure(figsize=(10, 20), dpi=180)
ax = sns.catplot(
    x='Relation type', y='MRR', 
    hue='Special type', col='Dataset', kind='box',
    data=pd.concat([sthg_fun_2, sthg_fun]).rename(columns={'MRR_hybrid': 'MRR', 
                                                           'relation_type': 'Relation type',
                                                           'type': 'Special type',
                                                           'eval_type': 'Dataset'}))
ax.savefig("MRR_relation_in_so_pairs (hybrid overall).png", dpi=180)

# %%
domain_similarity = pd.concat([result_subjects_plt, result_objects_plt])
domain_similarity = domain_similarity.groupby(['name_relation', 'relation_type', 'eval_type', 'MRR_hybrid', 'rank']).mean().reset_index()
domain_similarity['type'] = domain_similarity.name_relation.map(lambda x: 'Domain-sharing' if x in list_relation_in_so else 'Non domain-sharing')
domain_similarity['eval_type'] = domain_similarity.eval_type.map(lambda x: x.capitalize())
domain_similarity
# domain_similarity = domain_similarity.melt(id_vars=['name_relation', 'relation_type', 'eval_type', 'type', 'MRR_standard'],
#                                            value_vars=['First rank', 'Second rank', 'Third rank'], 
#                                             var_name='rank', value_name='jaccard_sim')
# domain_similarity
plt.figure(figsize=(10, 20), dpi=180)
ax = sns.catplot(x='Relation type', y='jaccard_sim', 
                 hue='Rank', row='Dataset', col='Special type',
                 kind='box', data=domain_similarity.rename(columns={'MRR_hybrid': 'MRR', 
                                                                    'relation_type': 'Relation type',
                                                                    'type': 'Special type',
                                                                    'eval_type': 'Dataset',
                                                                    'rank': 'Rank'}),
                 order=['M-N', 'M-1', '1-N', '1-1'],
                 )
ax.set(xlabel='Relation type', ylabel='Similarity with actual relation')
ax.savefig("jaccard_similarity (hybrid overall).png", dpi=180)

# %%
list_interesting_relations
# Out:
# array([], dtype=object)

# %%
## some examples of domain-sharing relations
type_of_relation = '1-1'
list_interesting_relations = domain_similarity[(domain_similarity.type == 'Domain-sharing') 
                  & (domain_similarity['rank'] == 'First rank')
                  # & (domain_similarity.jaccard_sim <= 0.6)
                  ].name_relation.unique()
# list_interesting_relations = ['/celebrities/celebrity/celebrity_friends./celebrities/friendship/friend']

df_std_hybrid_ranking[ df_std_hybrid_ranking.name_relation.isin(list_interesting_relations) 
                      & df_std_hybrid_ranking.relation_type.isin([type_of_relation]) 
                      & ~df_std_hybrid_ranking.so_to_p_hybrid.isin([0, 1, 2]) 
                    #   & (df_std_hybrid_ranking.name_subjects != df_std_hybrid_ranking.name_objects)
                      # & df_std_hybrid_ranking.predicted_relation_type_hybrid.isin([(type_of_relation, type_of_relation, type_of_relation)])
                      ]\
                          .set_index(['name_relation', 'relation_type', 
                                      'predicted_relation_hybrid', 'predicted_relation_type_hybrid'])
# Out:
#                                                                                                                                                                                 name_subjects  \
# name_relation                                      relation_type predicted_relation_hybrid                          predicted_relation_type_hybrid
# /dataworld/gardening_hint/split_to                 1-1           (/military/military_combatant/military_conflict... (M-N, M-N, M-N)                                  United States of America
# /location/country/capital                          1-1           (/location/location/adjoin_s./location/adjoinin... (M-N, M-N, M-N)                                                 Singapore
# /dataworld/gardening_hint/split_to                 1-1           (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                                                  Keyboard
# /base/aareas/schema/administrative_area/capital    1-1           (/dataworld/gardening_hint/split_to, /location/... (1-1, 1-1, 1-1)                                                     Paris
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                                               Mani Ratnam
# /organization/organization_founder/organization... 1-1           (/people/person/employment_history./business/em... (M-1, M-1, 1-N)                                            Cedric Gibbons
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                                       Kingdom of Scotland
# /people/person/sibling_s./people/sibling_relati... 1-1           (/base/popstra/celebrity/friendship./base/popst... (M-N, M-N, M-N)                                           Joaquin Phoenix
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                 Springfield (United States of America) #7
#                                                                  (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                          Florence (City/Town/Village) #81
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /common/topic/webpa... (M-N, M-1, M-N)                                                     Syria
# /people/person/sibling_s./people/sibling_relati... 1-1           (/location/hud_county_place/place, /education/e... (1-1, 1-1, 1-1)                                              Shemp Howard
# /location/hud_county_place/place                   1-1           (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                                                    Laredo
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_winning_work/awards_won./award/aw... (M-N, M-N, M-N)                                            Lindsay Crouse
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                                                Port Huron
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                                                     Egypt
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                   Albania
# /location/hud_county_place/place                   1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                    Danville (United States of America) #8
# /location/country/capital                          1-1           (/location/location/contains, /common/topic/web... (M-N, M-1, M-1)                                              West Germany
# /organization/organization_founder/organization... 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-1)                                          Andrew Scheinman
# /location/country/capital                          1-1           (/location/location/contains, /people/person/ge... (M-N, M-1, M-N)                                        Kingdom of England
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                Palm Beach
# /film/film/prequel                                 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                     The Lord of the Rings: The Two Towers
# /sports/sports_team_location/teams                 1-1           (/people/profession/specialization_of, /music/p... (M-1, M-N, M-N)                                                   Paisley
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                                             Wolverhampton
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                                                      Erie
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                             Rancho Mirage
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                                          Malcolm McDowell
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                                        Brian Doyle-Murray
# /sports/sports_team_location/teams                 1-1           (/music/performance_role/guest_performances./mu... (M-N, M-N, M-N)                                                   Geelong
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                                               Thomas Jane
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /location/locat... (M-1, M-N, M-N)                                                  Pakistan
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                                               Bill Murray
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                                             New York City
# /people/person/spouse_s./people/marriage/spouse    1-1           (/music/instrument/family, /music/performance_r... (M-1, M-N, M-N)                                               David Mamet
# /sports/sports_team_location/teams                 1-1           (/location/location/contains, /people/person/pr... (M-N, M-N, M-N)                                                      Peru
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                                                   Rosario
#                                                                  (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                                                   Walsall
# /location/us_county/county_seat                    1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                                            Lexington city
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                                           baritone guitar
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                            Greek Language
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /people/person/plac... (M-N, M-1, M-N)                                                  Malaysia
# /organization/organization_founder/organization... 1-1           (/people/person/place_of_birth, /music/performa... (M-1, M-N, M-N)                                            Herbert Hoover
# /sports/sports_team_location/teams                 1-1           (/music/instrument/instrumentalists, /common/to... (M-N, M-1, M-N)                    Stanford (United States of America) #5
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                  Amarillo
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /award/award_wi... (M-1, M-N, M-N)                                                 Argentina
# /film/film/prequel                                 1-1           (/dataworld/gardening_hint/split_to, /award/awa... (1-1, M-N, 1-1)                                  The Silence of the Lambs
# /organization/organization_founder/organization... 1-1           (/award/award_category/winners./award/award_hon... (M-N, M-1, M-1)                                           Abraham Lincoln
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                                       Kingdom of Portugal
#
#                                                                                                                                                                                          name_objects  \
# name_relation                                      relation_type predicted_relation_hybrid                          predicted_relation_type_hybrid
# /dataworld/gardening_hint/split_to                 1-1           (/military/military_combatant/military_conflict... (M-N, M-N, M-N)                                          United States of America
# /location/country/capital                          1-1           (/location/location/adjoin_s./location/adjoinin... (M-N, M-N, M-N)                                                         Singapore
# /dataworld/gardening_hint/split_to                 1-1           (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                                                          Keyboard
# /base/aareas/schema/administrative_area/capital    1-1           (/dataworld/gardening_hint/split_to, /location/... (1-1, 1-1, 1-1)                                                             Paris
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                                              Suhasini Mani Ratnam
# /organization/organization_founder/organization... 1-1           (/people/person/employment_history./business/em... (M-1, M-1, 1-N)                       Academy of Motion Picture Arts and Sciences
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                                                       Dunfermline
# /people/person/sibling_s./people/sibling_relati... 1-1           (/base/popstra/celebrity/friendship./base/popst... (M-N, M-N, M-N)                                                     River Phoenix
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                         Springfield (United States of America) #7
#                                                                  (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                                  Florence (City/Town/Village) #81
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /common/topic/webpa... (M-N, M-1, M-N)                                      Syria national football team
# /people/person/sibling_s./people/sibling_relati... 1-1           (/location/hud_county_place/place, /education/e... (1-1, 1-1, 1-1)                                                        Moe Howard
# /location/hud_county_place/place                   1-1           (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                                                            Laredo
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_winning_work/awards_won./award/aw... (M-N, M-N, M-N)                                                       David Mamet
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                                                        Port Huron
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                                                             Egypt
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                           Albania
# /location/hud_county_place/place                   1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                            Danville (United States of America) #8
# /location/country/capital                          1-1           (/location/location/contains, /common/topic/web... (M-N, M-1, M-1)                                                              Bonn
# /organization/organization_founder/organization... 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-1)                                         Castle Rock Entertainment
# /location/country/capital                          1-1           (/location/location/contains, /people/person/ge... (M-N, M-1, M-N)                                      Westminster (United Kingdom)
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                        Palm Beach
# /film/film/prequel                                 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                 The Lord of the Rings: The Fellowship of the Ring
# /sports/sports_team_location/teams                 1-1           (/people/profession/specialization_of, /music/p... (M-1, M-N, M-N)                                                   St. Mirren F.C.
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                                      Wolverhampton Wanderers F.C.
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                                                              Erie
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                     Rancho Mirage
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                                                  Mary Steenburgen
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                                                       Bill Murray
# /sports/sports_team_location/teams                 1-1           (/music/performance_role/guest_performances./mu... (M-N, M-N, M-N)                                             Geelong Football Club
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                                                 Patricia Arquette
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /location/locat... (M-1, M-N, M-N)                                   Pakistan national football team
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                                                Brian Doyle-Murray
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                                                     New York City
# /people/person/spouse_s./people/marriage/spouse    1-1           (/music/instrument/family, /music/performance_r... (M-1, M-N, M-N)                                                    Lindsay Crouse
# /sports/sports_team_location/teams                 1-1           (/location/location/contains, /people/person/pr... (M-N, M-N, M-N)                                       Peru national football team
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                                                 Newell's Old Boys
#                                                                  (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                                                      Walsall F.C.
# /location/us_county/county_seat                    1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                                                    Lexington city
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                                                   baritone guitar
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                    Greek Language
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /people/person/plac... (M-N, M-1, M-N)                                   Malaysia national football team
# /organization/organization_founder/organization... 1-1           (/people/person/place_of_birth, /music/performa... (M-1, M-N, M-N)                              Stanford Graduate School of Business
# /sports/sports_team_location/teams                 1-1           (/music/instrument/instrumentalists, /common/to... (M-N, M-1, M-N)                                        Stanford Cardinal football
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                                                          Amarillo
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /award/award_wi... (M-1, M-N, M-N)                                                      Boca Juniors
# /film/film/prequel                                 1-1           (/dataworld/gardening_hint/split_to, /award/awa... (1-1, M-N, 1-1)                                                        Red Dragon
# /organization/organization_founder/organization... 1-1           (/award/award_category/winners./award/award_hon... (M-N, M-1, M-1)                                          Internal Revenue Service
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                                                            Lisbon
#
#                                                                                                                                                    eval_type  \
# name_relation                                      relation_type predicted_relation_hybrid                          predicted_relation_type_hybrid
# /dataworld/gardening_hint/split_to                 1-1           (/military/military_combatant/military_conflict... (M-N, M-N, M-N)                    train
# /location/country/capital                          1-1           (/location/location/adjoin_s./location/adjoinin... (M-N, M-N, M-N)                    train
# /dataworld/gardening_hint/split_to                 1-1           (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                    train
# /base/aareas/schema/administrative_area/capital    1-1           (/dataworld/gardening_hint/split_to, /location/... (1-1, 1-1, 1-1)                    train
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                    valid
# /organization/organization_founder/organization... 1-1           (/people/person/employment_history./business/em... (M-1, M-1, 1-N)                    valid
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                    valid
# /people/person/sibling_s./people/sibling_relati... 1-1           (/base/popstra/celebrity/friendship./base/popst... (M-N, M-N, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                    valid
#                                                                  (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                    valid
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /common/topic/webpa... (M-N, M-1, M-N)                    valid
# /people/person/sibling_s./people/sibling_relati... 1-1           (/location/hud_county_place/place, /education/e... (1-1, 1-1, 1-1)                    valid
# /location/hud_county_place/place                   1-1           (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                    valid
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_winning_work/awards_won./award/aw... (M-N, M-N, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                    valid
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                    valid
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                    valid
# /location/country/capital                          1-1           (/location/location/contains, /common/topic/web... (M-N, M-1, M-1)                    valid
# /organization/organization_founder/organization... 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-1)                    valid
# /location/country/capital                          1-1           (/location/location/contains, /people/person/ge... (M-N, M-1, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                    valid
# /film/film/prequel                                 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                    valid
# /sports/sports_team_location/teams                 1-1           (/people/profession/specialization_of, /music/p... (M-1, M-N, M-N)                    valid
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                    valid
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                    valid
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                    valid
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                    valid
# /sports/sports_team_location/teams                 1-1           (/music/performance_role/guest_performances./mu... (M-N, M-N, M-N)                    valid
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                    valid
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /location/locat... (M-1, M-N, M-N)                    valid
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                    valid
# /people/person/spouse_s./people/marriage/spouse    1-1           (/music/instrument/family, /music/performance_r... (M-1, M-N, M-N)                    valid
# /sports/sports_team_location/teams                 1-1           (/location/location/contains, /people/person/pr... (M-N, M-N, M-N)                    valid
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                    valid
#                                                                  (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                    valid
# /location/us_county/county_seat                    1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                    valid
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                    valid
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                    valid
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /people/person/plac... (M-N, M-1, M-N)                    valid
# /organization/organization_founder/organization... 1-1           (/people/person/place_of_birth, /music/performa... (M-1, M-N, M-N)                    valid
# /sports/sports_team_location/teams                 1-1           (/music/instrument/instrumentalists, /common/to... (M-N, M-1, M-N)                    valid
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                    valid
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /award/award_wi... (M-1, M-N, M-N)                    valid
# /film/film/prequel                                 1-1           (/dataworld/gardening_hint/split_to, /award/awa... (1-1, M-N, 1-1)                    valid
# /organization/organization_founder/organization... 1-1           (/award/award_category/winners./award/award_hon... (M-N, M-1, M-1)                    valid
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                    valid
#
#                                                                                                                                                     so_to_p_hybrid  \
# name_relation                                      relation_type predicted_relation_hybrid                          predicted_relation_type_hybrid
# /dataworld/gardening_hint/split_to                 1-1           (/military/military_combatant/military_conflict... (M-N, M-N, M-N)                              6
# /location/country/capital                          1-1           (/location/location/adjoin_s./location/adjoinin... (M-N, M-N, M-N)                              3
# /dataworld/gardening_hint/split_to                 1-1           (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                              3
# /base/aareas/schema/administrative_area/capital    1-1           (/dataworld/gardening_hint/split_to, /location/... (1-1, 1-1, 1-1)                              4
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                            145
# /organization/organization_founder/organization... 1-1           (/people/person/employment_history./business/em... (M-1, M-1, 1-N)                              3
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                             39
# /people/person/sibling_s./people/sibling_relati... 1-1           (/base/popstra/celebrity/friendship./base/popst... (M-N, M-N, M-N)                             52
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                              4
#                                                                  (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                              4
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /common/topic/webpa... (M-N, M-1, M-N)                              4
# /people/person/sibling_s./people/sibling_relati... 1-1           (/location/hud_county_place/place, /education/e... (1-1, 1-1, 1-1)                             29
# /location/hud_county_place/place                   1-1           (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                             10
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_winning_work/awards_won./award/aw... (M-N, M-N, M-N)                             59
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                              5
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                              5
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                              9
# /location/hud_county_place/place                   1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                              4
# /location/country/capital                          1-1           (/location/location/contains, /common/topic/web... (M-N, M-1, M-1)                              6
# /organization/organization_founder/organization... 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-1)                              4
# /location/country/capital                          1-1           (/location/location/contains, /people/person/ge... (M-N, M-1, M-N)                              8
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                              3
# /film/film/prequel                                 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                              3
# /sports/sports_team_location/teams                 1-1           (/people/profession/specialization_of, /music/p... (M-1, M-N, M-N)                             31
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                              6
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                              7
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                              4
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                            127
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                             19
# /sports/sports_team_location/teams                 1-1           (/music/performance_role/guest_performances./mu... (M-N, M-N, M-N)                             29
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                             11
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /location/locat... (M-1, M-N, M-N)                              6
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                             20
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                              8
# /people/person/spouse_s./people/marriage/spouse    1-1           (/music/instrument/family, /music/performance_r... (M-1, M-N, M-N)                             48
# /sports/sports_team_location/teams                 1-1           (/location/location/contains, /people/person/pr... (M-N, M-N, M-N)                              6
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                             37
#                                                                  (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                             10
# /location/us_county/county_seat                    1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                             13
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                              5
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                              6
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /people/person/plac... (M-N, M-1, M-N)                              5
# /organization/organization_founder/organization... 1-1           (/people/person/place_of_birth, /music/performa... (M-1, M-N, M-N)                             54
# /sports/sports_team_location/teams                 1-1           (/music/instrument/instrumentalists, /common/to... (M-N, M-1, M-N)                             28
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                              4
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /award/award_wi... (M-1, M-N, M-N)                              5
# /film/film/prequel                                 1-1           (/dataworld/gardening_hint/split_to, /award/awa... (1-1, M-N, 1-1)                              3
# /organization/organization_founder/organization... 1-1           (/award/award_category/winners./award/award_hon... (M-N, M-1, M-1)                             30
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                              5
#
#                                                                                                                                                     MRR_hybrid
# name_relation                                      relation_type predicted_relation_hybrid                          predicted_relation_type_hybrid
# /dataworld/gardening_hint/split_to                 1-1           (/military/military_combatant/military_conflict... (M-N, M-N, M-N)                   0.950096
# /location/country/capital                          1-1           (/location/location/adjoin_s./location/adjoinin... (M-N, M-N, M-N)                   0.994718
# /dataworld/gardening_hint/split_to                 1-1           (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                   0.950096
# /base/aareas/schema/administrative_area/capital    1-1           (/dataworld/gardening_hint/split_to, /location/... (1-1, 1-1, 1-1)                   0.994161
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                   0.105845
# /organization/organization_founder/organization... 1-1           (/people/person/employment_history./business/em... (M-1, M-1, 1-N)                   0.621252
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                   0.349376
# /people/person/sibling_s./people/sibling_relati... 1-1           (/base/popstra/celebrity/friendship./base/popst... (M-N, M-N, M-N)                   0.229964
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                   0.697804
#                                                                  (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                   0.697804
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /common/topic/webpa... (M-N, M-1, M-N)                   0.686044
# /people/person/sibling_s./people/sibling_relati... 1-1           (/location/hud_county_place/place, /education/e... (1-1, 1-1, 1-1)                   0.229964
# /location/hud_county_place/place                   1-1           (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                   0.697804
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_winning_work/awards_won./award/aw... (M-N, M-N, M-N)                   0.105845
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                   0.697804
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                   0.144048
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                   0.144048
# /location/hud_county_place/place                   1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                   0.697804
# /location/country/capital                          1-1           (/location/location/contains, /common/topic/web... (M-N, M-1, M-1)                   0.349376
# /organization/organization_founder/organization... 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-1)                   0.621252
# /location/country/capital                          1-1           (/location/location/contains, /people/person/ge... (M-N, M-1, M-N)                   0.349376
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                   0.697804
# /film/film/prequel                                 1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, 1-1)                   0.615385
# /sports/sports_team_location/teams                 1-1           (/people/profession/specialization_of, /music/p... (M-1, M-N, M-N)                   0.686044
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                   0.686044
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, 1-1, 1-1)                   0.697804
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                   0.697804
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                   0.105845
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                   0.229964
# /sports/sports_team_location/teams                 1-1           (/music/performance_role/guest_performances./mu... (M-N, M-N, M-N)                   0.686044
# /people/person/spouse_s./people/marriage/spouse    1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                   0.105845
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /location/locat... (M-1, M-N, M-N)                   0.686044
# /people/person/sibling_s./people/sibling_relati... 1-1           (/influence/influence_node/influenced_by, /educ... (M-N, 1-1, M-N)                   0.229964
# /location/hud_county_place/place                   1-1           (/award/award_nominee/award_nominations./award/... (M-N, M-N, M-N)                   0.697804
# /people/person/spouse_s./people/marriage/spouse    1-1           (/music/instrument/family, /music/performance_r... (M-1, M-N, M-N)                   0.105845
# /sports/sports_team_location/teams                 1-1           (/location/location/contains, /people/person/pr... (M-N, M-N, M-N)                   0.686044
#                                                                  (/music/performance_role/regular_performances./... (M-N, M-N, M-N)                   0.686044
#                                                                  (/music/performance_role/track_performances./mu... (M-N, M-N, M-N)                   0.686044
# /location/us_county/county_seat                    1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, 1-1)                   0.071429
# /dataworld/gardening_hint/split_to                 1-1           (/education/educational_institution_campus/educ... (1-1, 1-1, M-N)                   0.144048
#                                                                  (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                   0.144048
# /sports/sports_team_location/teams                 1-1           (/people/person/profession, /people/person/plac... (M-N, M-1, M-N)                   0.686044
# /organization/organization_founder/organization... 1-1           (/people/person/place_of_birth, /music/performa... (M-1, M-N, M-N)                   0.621252
# /sports/sports_team_location/teams                 1-1           (/music/instrument/instrumentalists, /common/to... (M-N, M-1, M-N)                   0.686044
# /location/hud_county_place/place                   1-1           (/education/educational_institution/campuses, /... (1-1, 1-1, M-N)                   0.697804
# /sports/sports_team_location/teams                 1-1           (/people/person/place_of_birth, /award/award_wi... (M-1, M-N, M-N)                   0.686044
# /film/film/prequel                                 1-1           (/dataworld/gardening_hint/split_to, /award/awa... (1-1, M-N, 1-1)                   0.615385
# /organization/organization_founder/organization... 1-1           (/award/award_category/winners./award/award_hon... (M-N, M-1, M-1)                   0.621252
# /location/country/capital                          1-1           (/location/location/contains, /music/performanc... (M-N, M-N, M-N)                   0.349376
